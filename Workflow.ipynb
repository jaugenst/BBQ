# %%
from cellpose import models, io
from cellpose.io import *
from collections import defaultdict
import geopandas
import glob
import imagej
from jpype import JArray, JInt
import matplotlib.pyplot as plt
import multiprocessing as mp
import numpy as np
from math import isnan
import os
import pandas
from pandas import DataFrame
from pathlib import Path
import scyjava
import seaborn
import shutil

# %%
base_dir = '/home/saka/Documents/Lab stuff/confocal/exp2'
os.chdir(base_dir)
input_file = Path(f"{base_dir}/Experiment-1647-Split Scenes-01.czi").as_posix()
pandas.set_option('display.max_columns', None)
verbose = True

# %%
def start_fiji(base=None, mem='-Xmx30g', location='/home/saka/sw/local/fiji/2023', mode='interactive', input_file=None):
    scyjava.config.add_option(mem)
    start_dir = os.getcwd()
    if base:
        start_dir = base
    print(f"Where am I: {start_dir}")
    ij = imagej.init(Path(location), mode=mode)
    ij.getApp().getInfo(True)
    ij.ui().showUI()
    ## Something about this init() function changes the current working directory.
    os.chdir(start_dir)
    ij.getVersion()
    raw_image = None
    imp = None
    if input_file:
        raw_image = ij.io().open(input_file)
        shown = ij.ui().show(raw_image)
        imp = ij.py.to_imageplus(raw_image)
    return ij, raw_image, imp

# %%
scyjava.config.add_option('-Xmx30g')
start_dir = os.getcwd()
#ij = imagej.init('sc.fiji:fiji', mode='interactive')
ij = imagej.init('/home/saka/sw/local/fiji/2023', mode='interactive')
## Something about this init() function changes the current working directory.
ij.getApp().getInfo(True)
ij.ui().showUI()
os.chdir(start_dir)
ij.getVersion()
# Out:
# ({1: [29, 87], 2: [34, 91], 3: [44, 102], 4: [66, 122], 5: [67, 123], 6: [69, 125], 7: [70, 126], 8: [74, 132], 9: [81, 136], 10: [82, 137], 11: [105, 159], 12: [110, 163], 13: [120, 171, 228], 14: [141, 194, 250], 15: [153, 206], 16: [155, 209], 17: [157, 210], 18: [161, 216], 19: [164, 220], 20: [168, 225], 21: [170, 227], 22: [175, 232], 23: [213, 266], 24: [219, 272], 25: [226, 279], 26: [236, 290], 27: [243, 296], 28: [244, 298], 29: [265, 320], 30: [280, 335, 386], 31: [281, 336, 387], 32: [286, 339], 33: [291, 344], 34: [317, 368, 416, 463], 35: [324, 374], 36: [351, 399], 37: [352, 401], 38: [361, 408], 39: [372, 419, 466], 40: [389, 434], 41: [390, 435], 42: [394, 437, 486], 43: [397, 440], 44: [407, 452], 45: [431, 479], 46: [448, 496], 47: [464, 511], 48: [465, 510, 560, 612, 670, 721, 776], 49: [475, 523], 50: [477, 524], 51: [478, 525], 52: [482, 528, 580, 635, 690], 53: [484, 532], 54: [494, 543], 55: [516, 564], 56: [519, 567, 618], 57: [520, 568, 620, 677], 58: [526, 574], 59: [527, 579], 60: [561, 614, 671, 723, 777, 828, 881, 933], 61: [572, 626], 62: [573, 628], 63: [575, 631], 64: [577, 630], 65: [578, 633], 66: [586, 645], 67: [590, 648], 68: [600, 656], 69: [605, 662], 70: [611, 667], 71: [619, 676, 727], 72: [624, 680, 731], 73: [629, 685, 737], 74: [637, 691], 75: [638, 692], 76: [640, 695, 745], 77: [651, 703], 78: [678, 730, 785], 79: [684, 734, 789, 842], 80: [686, 738, 793], 81: [687, 739], 82: [697, 750, 804], 83: [700, 753], 84: [702, 754], 85: [717, 771], 86: [719, 773], 87: [720, 775], 88: [729, 783], 89: [733, 790], 90: [746, 803, 854], 91: [755, 809, 861, 914], 92: [779, 831], 93: [788, 840], 94: [792, 844], 95: [794, 845], 96: [796, 847], 97: [797, 851], 98: [802, 853, 906], 99: [805, 858, 911], 100: [812, 863, 917], 101: [813, 866], 102: [823, 876], 103: [826, 878], 104: [835, 888, 939], 105: [838, 892], 106: [848, 901], 107: [856, 909, 958], 108: [887, 938, 986], 109: [889, 940, 987], 110: [893, 945, 993, 1043], 111: [899, 949], 112: [903, 952], 113: [904, 953], 114: [908, 956], 115: [932, 981], 116: [936, 983], 117: [957, 1007], 118: [960, 1010], 119: [963, 1013, 1064], 120: [968, 1017], 121: [976, 1024], 122: [980, 1032], 123: [984, 1034, 1087], 124: [994, 1044, 1098, 1148], 125: [996, 1045, 1100, 1149, 1197], 126: [999, 1048], 127: [1000, 1051], 128: [1008, 1059, 1111, 1160, 1210, 1260], 129: [1015, 1065], 130: [1031, 1084, 1133], 131: [1069, 1120, 1169, 1218], 132: [1071, 1123, 1171], 133: [1077, 1129, 1178], 134: [1078, 1130], 135: [1083, 1134], 136: [1088, 1137], 137: [1090, 1141, 1189], 138: [1091, 1142, 1190, 1241], 139: [1096, 1146], 140: [1101, 1151, 1199], 141: [1103, 1153], 142: [1104, 1154], 143: [1107, 1157, 1207, 1258], 144: [1108, 1156], 145: [1110, 1159, 1209, 1259], 146: [1112, 1161], 147: [1127, 1176], 148: [1135, 1183], 149: [1139, 1188, 1239], 150: [1165, 1215, 1266, 1313, 1358], 151: [1167, 1216], 152: [1173, 1223], 153: [1196, 1247], 154: [1198, 1250, 1298], 155: [1203, 1255], 156: [1208, 1257], 157: [1212, 1261], 158: [1225, 1276], 159: [1237, 1286], 160: [1240, 1289, 1334], 161: [1246, 1294], 162: [1251, 1299, 1345, 1388, 1434, 1480, 1526, 1573, 1621, 1664], 163: [1252, 1300], 164: [1256, 1303], 165: [1278, 1323, 1367, 1413], 166: [1279, 1324], 167: [1282, 1327, 1371], 168: [1283, 1328], 169: [1284, 1329], 170: [1287, 1331], 171: [1288, 1333, 1377, 1422, 1467], 172: [1295, 1340], 173: [1307, 1352], 174: [1309, 1353], 175: [1315, 1360], 176: [1317, 1362], 177: [1321, 1365], 178: [1341, 1384], 179: [1349, 1391], 180: [1374, 1420, 1465], 181: [1390, 1436, 1482], 182: [1392, 1437], 183: [1393, 1439], 184: [1394, 1440], 185: [1397, 1443, 1488, 1535], 186: [1401, 1445, 1490], 187: [1403, 1448], 188: [1405, 1451], 189: [1411, 1455], 190: [1418, 1463, 1509], 191: [1423, 1468, 1514, 1560, 1606, 1652], 192: [1427, 1474, 1520, 1567, 1614], 193: [1430, 1477, 1524], 194: [1446, 1491], 195: [1458, 1503], 196: [1466, 1512, 1558, 1603], 197: [1475, 1521, 1569, 1616], 198: [1478, 15 ...
# 29      14820.0   1.094669       0.0       0.0      53.0      53.0       0.0
# 34      17654.0   1.191288       0.0       0.0      58.0      58.0       0.0
# 44      21887.0   0.773062       0.0       0.0      42.0      42.0       0.0
# 66      25335.0   0.704125       0.0       0.0      40.0      40.0       0.0
# 67      25294.0   4.696608       0.0       0.0     105.0     105.0       0.0
# ...         ...        ...       ...       ...       ...       ...       ...
# 4715    19512.0   0.601169       0.0       0.0      53.0      53.0       0.0
# 4716    28685.0   0.185079       0.0       0.0      28.0      28.0       0.0
# 4733    26269.0  34.844265       0.0       0.0     525.0     525.0       0.0
# 4734    12671.0   0.727172       0.0       0.0      34.0      34.0       0.0
# 4744    29703.0   0.202841       0.0       0.0      39.0      39.0       0.0
#
#       Min_left  Max_left  Max_left       X_left       Y_left  Skew_left  \
# 29         0.0      53.0      53.0  1358.485830  1049.325641   4.403371
# 34         0.0      58.0      58.0  1178.533420  1242.019599   4.115071
# 44         0.0      42.0      42.0   483.117353  1609.955065   4.922719
# 66         0.0      40.0      40.0  1651.610756   495.050069   5.008876
# 67         0.0     105.0     105.0  1461.245038   556.311220   2.140943
# ...        ...       ...       ...          ...          ...        ...
# 4715       0.0      53.0      53.0   227.778700  1090.582308   6.256732
# 4716       0.0      28.0      28.0  1293.500244  1232.365888   9.797194
# 4733       0.0     525.0     525.0   338.782843   538.862138   2.528663
# 4734       0.0      34.0      34.0   483.253611   544.978731   5.002105
# 4744       0.0      39.0      39.0  1289.442396  1226.643925   9.757399
#
#        Kurt_left  RawIntDen_left  Ch_left  Frame_left  \
# 29     23.891743         16223.0      1.0           0
# 34     20.846776         21031.0      1.0           0
# 44     28.227305         16920.0      1.0           0
# 66     28.321752         17839.0      1.0           1
# 67      5.908288        118796.0      1.0           1
# ...          ...             ...      ...         ...
# 4715   48.326763         11730.0      1.0         118
# 4716  109.082173          5309.0      1.0         118
# 4733    6.838675        915324.0      1.0         119
# 4734   28.133825          9214.0      1.0         119
# 4744  112.195446          6025.0      1.0         119
#
#                        geometry  index_right  Area_right  Mean_right  \
# 29    POINT (1358.486 1049.326)           87     17622.0    1.004199
# 34    POINT (1178.533 1242.020)           91     20296.0    0.792570
# 44     POINT (483.117 1609.955)          102     23587.0    0.739051
# 66     POINT (1651.611 495.050)          122     25952.0    0.688463
# 67     POINT (1461.245 556.311)          123     24202.0    4.830593
# ...                         ...          ...         ...         ...
# 4715   POINT (227.779 1090.582)         4743     19390.0    0.536772
# 4716  POINT (1293.500 1232.366)         4744     29703.0    0.202841
# 4733    POINT (338.783 538.862)         4763     26524.0   35.512178
# 4734    POINT (483.254 544.979)         4764     18360.0    0.765850
# 4744  POINT (1289.442 1226.644)         4772     28637.0    0.200370
#
#       Min_right  Min_right  Max_right  Max_right  Min_right  Min_right  \
# 29          0.0        0.0       63.0       63.0        0.0        0.0
# 34          0.0        0.0       37.0       37.0        0.0        0.0
# 44          0.0        0.0       35.0       35.0        0.0        0.0
# 66          0.0        0.0       47.0       47.0        0.0        0.0
# 67          0.0        0.0       78.0       78.0        0.0        0.0
# ...         ...        ...        ...        ...        ...        ...
# 4715        0.0        0.0       40.0       40.0        0.0        0.0
# 4716        0.0        0.0       39.0       39.0        0.0        0.0
# 4733        0.0        0.0      549.0      549.0        0.0        0.0
# 4734        0.0        0.0       42.0       42.0        0.0        0.0
# 4744        0.0        0.0       30.0       30.0        0.0        0.0
#
#       Max_right  Max_right      X_right      Y_right  Skew_right  Kurt_right  \
# 29         63.0       63.0  1357.825162  1040.113892    4.852356   31.228659
# 34         37.0       37.0  1186.830164  1241.945063    4.748408   25.303430
# 44         35.0       35.0   484.369165  1604.141794    4.801228   25.668322
# 66         47.0       47.0  1650.879855   485.955919    5.413801   35.705534
# 67         78.0       78.0  1463.182877   557.937898    2.030820    4.830495
# ...         ...        ...          ...          ...         ...         ...
# 4715       40.0       40.0   235.458638  1090.831047    6.156820   45.218556
# 4716       39.0       39.0  1289.442396  1226.643925    9.757399  112.195446
# 4733      549.0      549.0   334.618911   535.781594    2.937933    9.718748
# 4734       42.0       42.0   481.973529   544.663453    5.280132   34.194986
# 4744       30.0       30.0  1288.306055  1227.095453    9.453993  101.437168
#
#       RawIntDen_right  Ch_right  Frame_right  pairwise_dist
# 29            17696.0       1.0            1       9.235411
# 34            16086.0       1.0            1       8.297078
# 44            17432.0       1.0            1       5.946524
# 66            17867.0       1.0            2       9.123475
# 67           116910.0       1.0            2       2.530079
# ...               ...       ...          ...            ...
# 4715          10408.0       1.0          119       7.683965
# 4716           6025.0       1.0          119       7.014769
# 4733         941925.0       1.0          120       5.179583
# 4734          14061.0       1.0          120       1.318335
# 4744           5738.0       1.0          120       1.222763
#
# [862 rows x 37 columns], [    Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 29    14820.0   1.094669       0.0       0.0      53.0      53.0       0.0
#
#     Min_left  Max_left  Max_left      X_left       Y_left  Skew_left  \
# 29       0.0      53.0      53.0  1358.48583  1049.325641   4.403371
#
#     Kurt_left  RawIntDen_left  Ch_left  Frame_left                   geometry  \
# 29  23.891743         16223.0      1.0           0  POINT (1358.486 1049.326)
#
#     index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 29           87     17622.0    1.004199        0.0        0.0       63.0
#
#     Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 29       63.0        0.0        0.0       63.0       63.0  1357.825162
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 29  1040.113892    4.852356   31.228659          17696.0       1.0
#
#     Frame_right  pairwise_dist
# 29            1       9.235411  ,     Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 34    17654.0   1.191288       0.0       0.0      58.0      58.0       0.0
#
#     Min_left  Max_left  Max_left      X_left       Y_left  Skew_left  \
# 34       0.0      58.0      58.0  1178.53342  1242.019599   4.115071
#
#     Kurt_left  RawIntDen_left  Ch_left  Frame_left                   geometry  \
# 34  20.846776         21031.0      1.0           0  POINT (1178.533 1242.020)
#
#     index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 34           91     20296.0     0.79257        0.0        0.0       37.0
#
#     Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 34       37.0        0.0        0.0       37.0       37.0  1186.830164
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 34  1241.945063    4.748408    25.30343          16086.0       1.0
#
#     Frame_right  pairwise_dist
# 34            1       8.297078  ,     Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 44    21887.0   0.773062       0.0       0.0      42.0      42.0       0.0
#
#     Min_left  Max_left  Max_left      X_left       Y_left  Skew_left  \
# 44       0.0      42.0      42.0  483.117353  1609.955065   4.922719
#
#     Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 44  28.227305         16920.0      1.0           0  POINT (483.117 1609.955)
#
#     index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 44          102     23587.0    0.739051        0.0        0.0       35.0
#
#     Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 44       35.0        0.0        0.0       35.0       35.0  484.369165
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 44  1604.141794    4.801228   25.668322          17432.0       1.0
#
#     Frame_right  pairwise_dist
# 44            1       5.946524  ,     Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 66    25335.0   0.704125       0.0       0.0      40.0      40.0       0.0
#
#     Min_left  Max_left  Max_left       X_left      Y_left  Skew_left  \
# 66       0.0      40.0      40.0  1651.610756  495.050069   5.008876
#
#     Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 66  28.321752         17839.0      1.0           1  POINT (1651.611 495.050)
#
#     index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 66          122     25952.0    0.688463        0.0        0.0       47.0
#
#     Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 66       47.0        0.0        0.0       47.0       47.0  1650.879855
#
#        Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 66  485.955919    5.413801   35.705534          17867.0       1.0
#
#     Frame_right  pairwise_dist
# 66            2       9.123475  ,     Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 67    25294.0   4.696608       0.0       0.0     105.0     105.0       0.0
#
#     Min_left  Max_left  Max_left       X_left     Y_left  Skew_left  \
# 67       0.0     105.0     105.0  1461.245038  556.31122   2.140943
#
#     Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 67   5.908288        118796.0      1.0           1  POINT (1461.245 556.311)
#
#     index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 67          123     24202.0    4.830593        0.0        0.0       78.0
#
#     Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 67       78.0        0.0        0.0       78.0       78.0  1463.182877
#
#        Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 67  557.937898     2.03082    4.830495         116910.0       1.0
#
#     Frame_right  pairwise_dist
# 67            2       2.530079  ,     Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 69    28723.0   1.428193       0.0       0.0      56.0      56.0       0.0
#
#     Min_left  Max_left  Max_left      X_left      Y_left  Skew_left  \
# 69       0.0      56.0      56.0  154.053633  621.018295   3.792592
#
#     Kurt_left  RawIntDen_left  Ch_left  Frame_left                 geometry  \
# 69  17.931674         41022.0      1.0           1  POINT (154.054 621.018)
#
#     index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 69          125     27811.0    1.670778        0.0        0.0       89.0
#
#     Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 69       89.0        0.0        0.0       89.0       89.0  162.946514
#
#       Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  Frame_right  \
# 69  617.74947    3.567774   17.823841          46466.0       1.0            2
#
#     pairwise_dist
# 69       9.474627  ,     Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 70    27568.0   2.164575       0.0       0.0     120.0     120.0       0.0
#
#     Min_left  Max_left  Max_left       X_left      Y_left  Skew_left  \
# 70       0.0     120.0     120.0  1940.129861  627.178685   3.310453
#
#     Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 70  19.455035         59673.0      1.0           1  POINT (1940.130 627.179)
#
#     index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 70          126     27348.0    2.191678        0.0        0.0       55.0
#
#     Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 70       55.0        0.0        0.0       55.0       55.0  1944.925918
#
#        Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 70  621.523402    2.938514   10.199138          59938.0       1.0
#
#     Frame_right  pairwise_dist
# 70            2       7.415146  ,     Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 74    22759.0   1.230107       0.0       0.0      54.0      54.0       0.0
#
#     Min_left  Max_left  Max_left      X_left      Y_left  Skew_left  \
# 74       0.0      54.0      54.0  739.345468  737.836131   4.078684
#
#     Kurt_left  RawIntDen_left  Ch_left  Frame_left                 geometry  \
# 74  20.157072         27996.0      1.0           1  POINT (739.345 737.836)
#
#     index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 74          132     20777.0    1.268855        0.0        0.0       45.0
#
#     Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 74       45.0        0.0        0.0       45.0       45.0  744.409275
#
#        Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 74  741.698537    3.883713   17.426483          26363.0       1.0
#
#     Frame_right  pairwise_dist
# 74            2       6.368699  ,     Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 81    25283.0   1.709489       0.0       0.0      70.0      70.0       0.0
#
#     Min_left  Max_left  Max_left       X_left      Y_left  Skew_left  \
# 81       0.0      70.0      70.0  1406.284915  917.960586   3.689184
#
#     Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 81  18.039735         43221.0      1.0           1  POINT (1406.285 917.961)
#
#     index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 81          136     29749.0    1.691217        0.0        0.0       76.0
#
#     Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 81       76.0        0.0        0.0       76.0       76.0  1398.413442
#
#        Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 81  921.022942    3.562636   16.762199          50312.0       1.0
#
#     Frame_right  pairwise_dist
# 81            2       8.446188  ,     Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 82    40814.0   0.386118       0.0       0.0      61.0      61.0       0.0
#
#     Min_left  Max_left  Max_left       X_left      Y_left  Skew_left  \
# 82       0.0      61.0      61.0  1816.357157  955.341696   7.101866
#
#     Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 82  64.815254         15759.0      1.0           1  POINT (1816.357 955.342)
#
#     index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 82          137     37758.0    0.412019        0.0        0.0       36.0
#
#     Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 82       36.0        0.0        0.0       36.0       36.0  1820.247789
#
#        Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 82  946.778696    6.688141   51.319418          15557.0       1.0
#
#     Frame_right  pairwise_dist
# 82            2       9.405424  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 105    42349.0    0.55921       0.0       0.0      40.0      40.0       0.0
#
#      Min_left  Max_left  Max_left      X_left       Y_left  Skew_left  \
# 105       0.0      40.0      40.0  903.686545  1697.532161   5.714442
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 105  37.552904         23682.0      1.0           1  POINT (903.687 1697.532)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 105          159     41117.0    0.556509        0.0        0.0       44.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 105       44.0        0.0        0.0       44.0       44.0  907.025111
#
#          Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 105  1698.080684    5.815061   39.511977          22882.0       1.0
#
#      Frame_right  pairwise_dist
# 105            2       3.383327  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 110    20529.0   0.212431       0.0       0.0      31.0      31.0       0.0
#
#      Min_left  Max_left  Max_left       X_left       Y_left  Skew_left  \
# 110       0.0      31.0      31.0  1595.338619  1986.072556   8.917982
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left  \
# 110  89.752525          4361.0      1.0           1
#
#                       geometry  index_right  Area_right  Mean_right  \
# 110  POINT (1595.339 1986.073)          163     24950.0    0.218798
#
#      Min_right  Min_right  Max_right  Max_right  Min_right  Min_right  \
# 110        0.0        0.0       35.0       35.0        0.0        0.0
#
#      Max_right  Max_right      X_right      Y_right  Skew_right  Kurt_right  \
# 110       35.0       35.0  1590.623407  1979.558597    9.265913   100.61706
#
#      RawIntDen_right  Ch_right  Frame_right  pairwise_dist
# 110           5459.0       1.0            2       8.041448  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 120    30412.0   0.476391       0.0       0.0      69.0      69.0       0.0
#
#      Min_left  Max_left  Max_left       X_left      Y_left  Skew_left  \
# 120       0.0      69.0      69.0  1817.683316  399.972215   6.889368
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 120  66.409979         14488.0      1.0           2  POINT (1817.683 399.972)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 120          171     28437.0    0.448676        0.0        0.0       41.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 120       41.0        0.0        0.0       41.0       41.0  1811.71785
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 120  394.451542    6.554449   50.472822          12759.0       1.0
#
#      Frame_right  pairwise_dist
# 120            3       8.128014  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 141    12725.0   0.822318       0.0       0.0      44.0      44.0       0.0
#
#      Min_left  Max_left  Max_left      X_left       Y_left  Skew_left  \
# 141       0.0      44.0      44.0  440.060079  1052.174106   5.004951
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 141  30.345209         10464.0      1.0           2  POINT (440.060 1052.174)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 141          194     18049.0    0.737437        0.0        0.0       56.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right    X_right  \
# 141       56.0        0.0        0.0       56.0       56.0  437.12081
#
#          Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 141  1052.602056    5.320117   35.425908          13310.0       1.0
#
#      Frame_right  pairwise_dist
# 141            3       2.970259  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 153    21230.0   0.415214       0.0       0.0      32.0      32.0       0.0
#
#      Min_left  Max_left  Max_left      X_left      Y_left  Skew_left  \
# 153       0.0      32.0      32.0  383.643947  1519.34635   6.590186
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 153  49.684945          8815.0      1.0           2  POINT (383.644 1519.346)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 153          206     17346.0    0.460164        0.0        0.0       34.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 153       34.0        0.0        0.0       34.0       34.0  388.501095
#
#          Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 153  1512.187017    6.300936   45.542566           7982.0       1.0
#
#      Frame_right  pairwise_dist
# 153            3        8.65147  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 155    20783.0   0.744455       0.0       0.0      45.0      45.0       0.0
#
#      Min_left  Max_left  Max_left      X_left       Y_left  Skew_left  \
# 155       0.0      45.0      45.0  501.001083  1609.710894   5.000733
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 155  29.876512         15472.0      1.0           2  POINT (501.001 1609.711)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 155          209     22383.0    0.712862        0.0        0.0       31.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 155       31.0        0.0        0.0       31.0       31.0  499.635103
#
#          Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 155  1614.089689    4.980987   27.818178          15956.0       1.0
#
#      Frame_right  pairwise_dist
# 155            3       4.586911  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 157    24581.0   0.178064       0.0       0.0      25.0      25.0       0.0
#
#      Min_left  Max_left  Max_left      X_left       Y_left  Skew_left  \
# 157       0.0      25.0      25.0  1819.91048  1641.274379   9.852309
#
#       Kurt_left  RawIntDen_left  Ch_left  Frame_left  \
# 157  109.507107          4377.0      1.0           2
#
#                       geometry  index_right  Area_right  Mean_right  \
# 157  POINT (1819.910 1641.274)          210     25486.0    0.169505
#
#      Min_right  Min_right  Max_right  Max_right  Min_right  Min_right  \
# 157        0.0        0.0       35.0       35.0        0.0        0.0
#
#      Max_right  Max_right      X_right      Y_right  Skew_right  Kurt_right  \
# 157       35.0       35.0  1816.785569  1635.331084   10.610947  131.470534
#
#      RawIntDen_right  Ch_right  Frame_right  pairwise_dist
# 157           4320.0       1.0            3       6.714747  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 161    46566.0   0.082549       0.0       0.0      30.0      30.0       0.0
#
#      Min_left  Max_left  Max_left       X_left       Y_left  Skew_left  \
# 161       0.0      30.0      30.0  1918.571769  1958.450071  15.046918
#
#       Kurt_left  RawIntDen_left  Ch_left  Frame_left  \
# 161  260.392002          3844.0      1.0           2
#
#                       geometry  index_right  Area_right  Mean_right  \
# 161  POINT (1918.572 1958.450)          216     43194.0    0.087998
#
#      Min_right  Min_right  Max_right  Max_right  Min_right  Min_right  \
# 161        0.0        0.0       30.0       30.0        0.0        0.0
#
#      Max_right  Max_right     X_right      Y_right  Skew_right  Kurt_right  \
# 161       30.0       30.0  1926.01447  1957.304186   14.840987  255.068502
#
#      RawIntDen_right  Ch_right  Frame_right  pairwise_dist
# 161           3801.0       1.0            3       7.530395  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 164    25525.0   0.725367       0.0       0.0      54.0      54.0       0.0
#
#      Min_left  Max_left  Max_left       X_left      Y_left  Skew_left  \
# 164       0.0      54.0      54.0  1979.729971  179.301293   5.104014
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 164   31.40907         18515.0      1.0           3  POINT (1979.730 179.301)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 164          220     23846.0    0.809905        0.0        0.0       38.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 164       38.0        0.0        0.0       38.0       38.0  1988.323576
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 164  177.868783    4.791007   25.998185          19313.0       1.0
#
#      Frame_right  pairwise_dist
# 164            4       8.712184  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 168    12428.0   3.914387       0.0       0.0      61.0      61.0       0.0
#
#      Min_left  Max_left  Max_left       X_left      Y_left  Skew_left  \
# 168       0.0      61.0      61.0  1762.101786  204.614902   2.307949
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 168   6.459776         48648.0      1.0           3  POINT (1762.102 204.615)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 168          225     11777.0    3.783816        0.0        0.0       74.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 168       74.0        0.0        0.0       74.0       74.0  1766.460431
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 168  197.100917     2.35455    6.773865          44562.0       1.0
#
#      Frame_right  pairwise_dist
# 168            4       8.686642  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 170    20153.0   4.067136       0.0       0.0     125.0     125.0       0.0
#
#      Min_left  Max_left  Max_left      X_left      Y_left  Skew_left  \
# 170       0.0     125.0     125.0  1277.51042  327.844018   2.441187
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 170   9.932703         81965.0      1.0           3  POINT (1277.510 327.844)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 170          227     18672.0    4.145351        0.0        0.0       62.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 170       62.0        0.0        0.0       62.0       62.0  1278.986397
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 170  333.422076    2.191382    5.592812          77402.0       1.0
#
#      Frame_right  pairwise_dist
# 170            4       5.770029  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 171    28437.0   0.448676       0.0       0.0      41.0      41.0       0.0
#
#      Min_left  Max_left  Max_left      X_left      Y_left  Skew_left  \
# 171       0.0      41.0      41.0  1811.71785  394.451542   6.554449
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 171  50.472822         12759.0      1.0           3  POINT (1811.718 394.452)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 171          228     24477.0    0.544552        0.0        0.0       42.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 171       42.0        0.0        0.0       42.0       42.0  1806.568881
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 171  396.702762    5.888783   41.390992          13329.0       1.0
#
#      Frame_right  pairwise_dist
# 171            4       5.619597  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 175    25593.0   4.335873       0.0       0.0      86.0      86.0       0.0
#
#      Min_left  Max_left  Max_left      X_left      Y_left  Skew_left  \
# 175       0.0      86.0      86.0  1476.19437  549.660747   2.286421
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 175   6.864803        110968.0      1.0           3  POINT (1476.194 549.661)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 175          232     24214.0    4.273602        0.0        0.0       68.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 175       68.0        0.0        0.0       68.0       68.0  1481.648798
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 175  550.093706    2.214365    6.025953         103481.0       1.0
#
#      Frame_right  pairwise_dist
# 175            4       5.471585  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 194    18049.0   0.737437       0.0       0.0      56.0      56.0       0.0
#
#      Min_left  Max_left  Max_left     X_left       Y_left  Skew_left  \
# 194       0.0      56.0      56.0  437.12081  1052.602056   5.320117
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 194  35.425908         13310.0      1.0           3  POINT (437.121 1052.602)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 194          250     22436.0    0.810394        0.0        0.0       39.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 194       39.0        0.0        0.0       39.0       39.0  432.650339
#
#          Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 194  1049.594892    4.946867   28.450616          18182.0       1.0
#
#      Frame_right  pairwise_dist
# 194            4       5.387777  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 213    37859.0   0.535117       0.0       0.0      80.0      80.0       0.0
#
#      Min_left  Max_left  Max_left      X_left       Y_left  Skew_left  \
# 213       0.0      80.0      80.0  924.285863  1722.849745   6.513966
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 213   62.70642         20259.0      1.0           3  POINT (924.286 1722.850)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 213          266     39633.0    0.631115        0.0        0.0       40.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 213       40.0        0.0        0.0       40.0       40.0  930.755242
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 213  1722.15612    5.474334   34.731092          25013.0       1.0
#
#      Frame_right  pairwise_dist
# 213            4       6.506456  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 219    24190.0   0.228276       0.0       0.0      38.0      38.0       0.0
#
#      Min_left  Max_left  Max_left       X_left       Y_left  Skew_left  \
# 219       0.0      38.0      38.0  1597.377387  1987.621786   9.225737
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left  \
# 219  99.254315          5522.0      1.0           3
#
#                       geometry  index_right  Area_right  Mean_right  \
# 219  POINT (1597.377 1987.622)          272     21578.0    0.262443
#
#      Min_right  Min_right  Max_right  Max_right  Min_right  Min_right  \
# 219        0.0        0.0       32.0       32.0        0.0        0.0
#
#      Max_right  Max_right      X_right      Y_right  Skew_right  Kurt_right  \
# 219       32.0       32.0  1603.440263  1983.125452    8.324325   81.017433
#
#      RawIntDen_right  Ch_right  Frame_right  pairwise_dist
# 219           5663.0       1.0            4       7.548211  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 226    31556.0    1.67892       0.0       0.0      61.0      61.0       0.0
#
#      Min_left  Max_left  Max_left       X_left      Y_left  Skew_left  \
# 226       0.0      61.0      61.0  1507.508366  313.909906   3.688637
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 226  16.932672         52980.0      1.0           4  POINT (1507.508 313.910)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 226          279     34248.0    1.596736        0.0        0.0       59.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 226       59.0        0.0        0.0       59.0       59.0  1500.950566
#
#        Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 226  314.71394    3.550445   14.881039          54685.0       1.0
#
#      Frame_right  pairwise_dist
# 226            5       6.606906  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 236    25247.0   0.383491       0.0       0.0      48.0      48.0       0.0
#
#      Min_left  Max_left  Max_left      X_left      Y_left  Skew_left  \
# 236       0.0      48.0      48.0  627.065334  613.596209   7.055148
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                 geometry  \
# 236  61.590063          9682.0      1.0           4  POINT (627.065 613.596)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 236          290     25178.0    0.452419        0.0        0.0       35.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 236       35.0        0.0        0.0       35.0       35.0  627.285527
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 236  615.879895    6.265719   44.361398          11391.0       1.0
#
#      Frame_right  pairwise_dist
# 236            5       2.294277  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 243    16466.0   1.667618       0.0       0.0      48.0      48.0       0.0
#
#      Min_left  Max_left  Max_left       X_left      Y_left  Skew_left  \
# 243       0.0      48.0      48.0  1080.523807  824.255678   3.234167
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 243  11.599324         27459.0      1.0           4  POINT (1080.524 824.256)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 243          296     16519.0    1.777347        0.0        0.0       69.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 243       69.0        0.0        0.0       69.0       69.0  1072.770355
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 243  819.857225    3.314103   13.828593          29360.0       1.0
#
#      Frame_right  pairwise_dist
# 243            5       8.914168  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 244    18900.0    2.97164       0.0       0.0      58.0      58.0       0.0
#
#      Min_left  Max_left  Max_left     X_left      Y_left  Skew_left  \
# 244       0.0      58.0      58.0  718.70836  866.583492   2.484156
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                 geometry  \
# 244    6.96468         56164.0      1.0           4  POINT (718.708 866.583)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 244          298     18773.0    3.127204        0.0        0.0       86.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 244       86.0        0.0        0.0       86.0       86.0  723.147739
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 244  864.550924    2.579631    9.413975          58707.0       1.0
#
#      Frame_right  pairwise_dist
# 244            5       4.882563  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 265    41571.0   0.787496       0.0       0.0      60.0      60.0       0.0
#
#      Min_left  Max_left  Max_left      X_left       Y_left  Skew_left  \
# 265       0.0      60.0      60.0  718.229451  1692.317637   5.108213
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 265  32.796892         32737.0      1.0           4  POINT (718.229 1692.318)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 265          320     37154.0    0.861415        0.0        0.0       44.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 265       44.0        0.0        0.0       44.0       44.0  720.865183
#
#          Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 265  1689.443075    4.586429   23.924863          32005.0       1.0
#
#      Frame_right  pairwise_dist
# 265            5       3.900025  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 280    18539.0   4.238147       0.0       0.0      69.0      69.0       0.0
#
#      Min_left  Max_left  Max_left       X_left     Y_left  Skew_left  \
# 280       0.0      69.0      69.0  1289.675252  338.05305   2.204484
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 280   5.799781         78571.0      1.0           5  POINT (1289.675 338.053)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 280          335     20412.0    4.041201        0.0        0.0       99.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 280       99.0        0.0        0.0       99.0       99.0  1290.094552
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 280  341.743239    2.294157    7.267389          82489.0       1.0
#
#      Frame_right  pairwise_dist
# 280            6       3.713934  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 281    27881.0   0.495355       0.0       0.0      42.0      42.0       0.0
#
#      Min_left  Max_left  Max_left       X_left     Y_left  Skew_left  \
# 281       0.0      42.0      42.0  1827.428482  385.00755   6.032081
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 281  42.240719         13811.0      1.0           5  POINT (1827.428 385.008)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 281          336     27725.0    0.548783        0.0        0.0       46.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 281       46.0        0.0        0.0       46.0       46.0  1829.047304
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 281  389.348909    5.701137    38.27414          15215.0       1.0
#
#      Frame_right  pairwise_dist
# 281            6       4.633355  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 286    25736.0   4.131528       0.0       0.0      68.0      68.0       0.0
#
#      Min_left  Max_left  Max_left     X_left      Y_left  Skew_left  \
# 286       0.0      68.0      68.0  1495.3553  544.481116   2.225389
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 286   5.945356        106329.0      1.0           5  POINT (1495.355 544.481)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 286          339     27370.0    3.795433        0.0        0.0       60.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 286       60.0        0.0        0.0       60.0       60.0  1494.84852
#
#        Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 286  545.37194    2.269475    5.924586         103881.0       1.0
#
#      Frame_right  pairwise_dist
# 286            6       1.024887  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 291    11515.0   0.954494       0.0       0.0      42.0      42.0       0.0
#
#      Min_left  Max_left  Max_left      X_left      Y_left  Skew_left  \
# 291       0.0      42.0      42.0  875.541424  599.309553   4.447857
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                 geometry  \
# 291  23.010902         10991.0      1.0           5  POINT (875.541 599.310)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 291          344     12715.0    1.074636        0.0        0.0       43.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 291       43.0        0.0        0.0       43.0       43.0  878.403107
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 291  596.860283    4.217965   21.066319          13664.0       1.0
#
#      Frame_right  pairwise_dist
# 291            6       3.766716  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 317    20795.0   0.653234       0.0       0.0      37.0      37.0       0.0
#
#      Min_left  Max_left  Max_left      X_left       Y_left  Skew_left  \
# 317       0.0      37.0      37.0  512.702933  1589.394927   5.317441
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 317  32.322928         13584.0      1.0           5  POINT (512.703 1589.395)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 317          368     22505.0     0.63026        0.0        0.0       47.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 317       47.0        0.0        0.0       47.0       47.0  509.144079
#
#          Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 317  1594.863919    5.414702   34.249144          14184.0       1.0
#
#      Frame_right  pairwise_dist
# 317            6       6.524977  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 324    25110.0    0.14544       0.0       0.0      27.0      27.0       0.0
#
#      Min_left  Max_left  Max_left      X_left       Y_left  Skew_left  \
# 324       0.0      27.0      27.0  522.920311  1858.867145  11.011608
#
#       Kurt_left  RawIntDen_left  Ch_left  Frame_left  \
# 324  136.917946          3652.0      1.0           5
#
#                      geometry  index_right  Area_right  Mean_right  Min_right  \
# 324  POINT (522.920 1858.867)          374     21996.0    0.166712        0.0
#
#      Min_right  Max_right  Max_right  Min_right  Min_right  Max_right  \
# 324        0.0       30.0       30.0        0.0        0.0       30.0
#
#      Max_right     X_right      Y_right  Skew_right  Kurt_right  \
# 324       30.0  524.369795  1856.502046   10.987963  138.968122
#
#      RawIntDen_right  Ch_right  Frame_right  pairwise_dist
# 324           3667.0       1.0            6       2.773931  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 335    20412.0   4.041201       0.0       0.0      99.0      99.0       0.0
#
#      Min_left  Max_left  Max_left       X_left      Y_left  Skew_left  \
# 335       0.0      99.0      99.0  1290.094552  341.743239   2.294157
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 335   7.267389         82489.0      1.0           6  POINT (1290.095 341.743)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 335          386     20589.0    4.137792        0.0        0.0       67.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 335       67.0        0.0        0.0       67.0       67.0  1290.154233
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 335  332.528705    2.209837    5.972954          85193.0       1.0
#
#      Frame_right  pairwise_dist
# 335            7       9.214728  ,      Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 336    27725.0   0.548783       0.0       0.0      46.0      46.0       0.0
#
#      Min_left  Max_left  Max_left       X_left      Y_left  Skew_left  \
# 336       0.0      46.0      46.0  1829.047304  389.348909   5.701137
#
#      Kurt_left  RawIntDen_left  Ch_left  Frame_left                  geometry  \
# 336   38.27414         15215.0      1.0           6  POINT (1829.047 389.349)
#
#      index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 336          387     26287.0     0.65987        0.0        0.0       57.0
#
#      Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 336       57.0        0.0        0.0       57.0       57.0  1825.057234
#
# ...
# 4646          117       9.003016  ,       Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 4651    13630.0   0.341233       0.0       0.0      28.0      28.0       0.0
#
#       Min_left  Max_left  Max_left      X_left      Y_left  Skew_left  \
# 4651       0.0      28.0      28.0  519.418122  395.639032   7.292873
#
#       Kurt_left  RawIntDen_left  Ch_left  Frame_left                 geometry  \
# 4651  59.676802          4651.0      1.0         116  POINT (519.418 395.639)
#
#       index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 4651         4676     14062.0    0.393116        0.0        0.0       36.0
#
#       Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 4651       36.0        0.0        0.0       36.0       36.0  521.434078
#
#          Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 4651  395.973119    6.961134   56.470243           5528.0       1.0
#
#       Frame_right  pairwise_dist
# 4651          117       2.043451  ,       Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 4656    40997.0   0.849013       0.0       0.0     127.0     127.0       0.0
#
#       Min_left  Max_left  Max_left     X_left      Y_left  Skew_left  \
# 4656       0.0     127.0     127.0  509.89959  588.739944   6.951516
#
#       Kurt_left  RawIntDen_left  Ch_left  Frame_left                 geometry  \
# 4656  94.267557         34807.0      1.0         116  POINT (509.900 588.740)
#
#       index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 4656         4682     32783.0     0.71656        0.0        0.0       45.0
#
#       Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 4656       45.0        0.0        0.0       45.0       45.0  512.604658
#
#          Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 4656  590.484413    5.293528   33.730675          23491.0       1.0
#
#       Frame_right  pairwise_dist
# 4656          117       3.218782  ,       Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 4657    24340.0  31.805505       0.0       0.0     579.0     579.0       0.0
#
#       Min_left  Max_left  Max_left      X_left      Y_left  Skew_left  \
# 4657       0.0     579.0     579.0  344.054232  565.206039   3.671344
#
#       Kurt_left  RawIntDen_left  Ch_left  Frame_left                 geometry  \
# 4657  16.112112        774146.0      1.0         116  POINT (344.054 565.206)
#
#       index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 4657         4681     28800.0   35.281806        0.0        0.0      797.0
#
#       Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 4657      797.0        0.0        0.0      797.0      797.0  339.612917
#
#          Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 4657  570.105833    3.556956   16.349699        1016116.0       1.0
#
#       Frame_right  pairwise_dist
# 4657          117       6.613113  ,       Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 4660    38292.0   0.204951       0.0       0.0      32.0      32.0       0.0
#
#       Min_left  Max_left  Max_left       X_left       Y_left  Skew_left  \
# 4660       0.0      32.0      32.0  1276.907265  1242.741852   9.504655
#
#        Kurt_left  RawIntDen_left  Ch_left  Frame_left  \
# 4660  104.559706          7848.0      1.0         116
#
#                        geometry  index_right  Area_right  Mean_right  \
# 4660  POINT (1276.907 1242.742)         4688     37010.0    0.191192
#
#       Min_right  Min_right  Max_right  Max_right  Min_right  Min_right  \
# 4660        0.0        0.0       34.0       34.0        0.0        0.0
#
#       Max_right  Max_right      X_right      Y_right  Skew_right  Kurt_right  \
# 4660       34.0       34.0  1278.778249  1240.739503    9.783133  109.649799
#
#       RawIntDen_right  Ch_right  Frame_right  pairwise_dist
# 4660           7076.0       1.0          117       2.740435  ,       Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 4671    18075.0   5.419142       0.0       0.0     143.0     143.0       0.0
#
#       Min_left  Max_left  Max_left       X_left     Y_left  Skew_left  \
# 4671       0.0     143.0     143.0  1766.016349  70.126058   2.135885
#
#       Kurt_left  RawIntDen_left  Ch_left  Frame_left                 geometry  \
# 4671   8.270654         97951.0      1.0         117  POINT (1766.016 70.126)
#
#       index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 4671         4699     19749.0    5.218138        0.0        0.0       81.0
#
#       Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 4671       81.0        0.0        0.0       81.0       81.0  1772.392349
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 4671  70.258317    1.952714    4.552133         103053.0       1.0
#
#       Frame_right  pairwise_dist
# 4671          118       6.377372  ,       Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 4676    14062.0   0.393116       0.0       0.0      36.0      36.0       0.0
#
#       Min_left  Max_left  Max_left      X_left      Y_left  Skew_left  \
# 4676       0.0      36.0      36.0  521.434078  395.973119   6.961134
#
#       Kurt_left  RawIntDen_left  Ch_left  Frame_left                 geometry  \
# 4676  56.470243          5528.0      1.0         117  POINT (521.434 395.973)
#
#       index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 4676         4703     15755.0    0.432307        0.0        0.0       40.0
#
#       Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 4676       40.0        0.0        0.0       40.0       40.0  513.708886
#
#          Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 4676  400.516757    6.724508   53.870994           6811.0       1.0
#
#       Frame_right  pairwise_dist
# 4676          118       8.962323  ,       Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 4685    12591.0   32.79676       0.0       0.0     373.0     373.0       0.0
#
#       Min_left  Max_left  Max_left      X_left     Y_left  Skew_left  \
# 4685       0.0     373.0     373.0  496.996466  753.10575   2.105888
#
#       Kurt_left  RawIntDen_left  Ch_left  Frame_left                 geometry  \
# 4685   4.960668        412944.0      1.0         117  POINT (496.996 753.106)
#
#       index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 4685         4713     14325.0   26.608866        0.0        0.0      399.0
#
#       Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 4685      399.0        0.0        0.0      399.0      399.0  491.586702
#
#          Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 4685  756.773368    2.224566    5.736872         381172.0       1.0
#
#       Frame_right  pairwise_dist
# 4685          118       6.535822  ,       Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 4699    19749.0   5.218138       0.0       0.0      81.0      81.0       0.0
#
#       Min_left  Max_left  Max_left       X_left     Y_left  Skew_left  \
# 4699       0.0      81.0      81.0  1772.392349  70.258317   1.952714
#
#       Kurt_left  RawIntDen_left  Ch_left  Frame_left                 geometry  \
# 4699   4.552133        103053.0      1.0         118  POINT (1772.392 70.258)
#
#       index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 4699         4724     19451.0    5.194129        0.0        0.0       63.0
#
#       Max_right  Min_right  Min_right  Max_right  Max_right      X_right  \
# 4699       63.0        0.0        0.0       63.0       63.0  1768.922446
#
#         Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 4699  77.746825    1.937179    4.371583         101031.0       1.0
#
#       Frame_right  pairwise_dist
# 4699          119       8.253362  ,       Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 4703    15755.0   0.432307       0.0       0.0      40.0      40.0       0.0
#
#       Min_left  Max_left  Max_left      X_left      Y_left  Skew_left  \
# 4703       0.0      40.0      40.0  513.708886  400.516757   6.724508
#
#       Kurt_left  RawIntDen_left  Ch_left  Frame_left                 geometry  \
# 4703  53.870994          6811.0      1.0         118  POINT (513.709 400.517)
#
#       index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 4703         4728     15435.0    0.424166        0.0        0.0       38.0
#
#       Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 4703       38.0        0.0        0.0       38.0       38.0  517.808714
#
#          Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 4703  393.082637    6.686956   52.028914           6547.0       1.0
#
#       Frame_right  pairwise_dist
# 4703          119       8.489683  ,       Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 4709    14169.0    0.70132       0.0       0.0      48.0      48.0       0.0
#
#       Min_left  Max_left  Max_left      X_left      Y_left  Skew_left  \
# 4709       0.0      48.0      48.0  489.793528  545.453843     5.5121
#
#       Kurt_left  RawIntDen_left  Ch_left  Frame_left                 geometry  \
# 4709  37.231526          9937.0      1.0         118  POINT (489.794 545.454)
#
#       index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 4709         4734     12671.0    0.727172        0.0        0.0       34.0
#
#       Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 4709       34.0        0.0        0.0       34.0       34.0  483.253611
#
#          Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 4709  544.978731    5.002105   28.133825           9214.0       1.0
#
#       Frame_right  pairwise_dist
# 4709          119       6.557153  ,       Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 4714    19405.0   0.894872       0.0       0.0      51.0      51.0       0.0
#
#       Min_left  Max_left  Max_left      X_left       Y_left  Skew_left  \
# 4714       0.0      51.0      51.0  1075.88655  1012.436254   4.832448
#
#       Kurt_left  RawIntDen_left  Ch_left  Frame_left  \
# 4714  28.778946         17365.0      1.0         118
#
#                        geometry  index_right  Area_right  Mean_right  \
# 4714  POINT (1075.887 1012.436)         4742     22204.0     0.90209
#
#       Min_right  Min_right  Max_right  Max_right  Min_right  Min_right  \
# 4714        0.0        0.0       45.0       45.0        0.0        0.0
#
#       Max_right  Max_right      X_right     Y_right  Skew_right  Kurt_right  \
# 4714       45.0       45.0  1074.477166  1012.49964     4.58153   24.573444
#
#       RawIntDen_right  Ch_right  Frame_right  pairwise_dist
# 4714          20030.0       1.0          119       1.410808  ,       Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 4715    19512.0   0.601169       0.0       0.0      53.0      53.0       0.0
#
#       Min_left  Max_left  Max_left    X_left       Y_left  Skew_left  \
# 4715       0.0      53.0      53.0  227.7787  1090.582308   6.256732
#
#       Kurt_left  RawIntDen_left  Ch_left  Frame_left  \
# 4715  48.326763         11730.0      1.0         118
#
#                       geometry  index_right  Area_right  Mean_right  \
# 4715  POINT (227.779 1090.582)         4743     19390.0    0.536772
#
#       Min_right  Min_right  Max_right  Max_right  Min_right  Min_right  \
# 4715        0.0        0.0       40.0       40.0        0.0        0.0
#
#       Max_right  Max_right     X_right      Y_right  Skew_right  Kurt_right  \
# 4715       40.0       40.0  235.458638  1090.831047     6.15682   45.218556
#
#       RawIntDen_right  Ch_right  Frame_right  pairwise_dist
# 4715          10408.0       1.0          119       7.683965  ,       Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 4716    28685.0   0.185079       0.0       0.0      28.0      28.0       0.0
#
#       Min_left  Max_left  Max_left       X_left       Y_left  Skew_left  \
# 4716       0.0      28.0      28.0  1293.500244  1232.365888   9.797194
#
#        Kurt_left  RawIntDen_left  Ch_left  Frame_left  \
# 4716  109.082173          5309.0      1.0         118
#
#                        geometry  index_right  Area_right  Mean_right  \
# 4716  POINT (1293.500 1232.366)         4744     29703.0    0.202841
#
#       Min_right  Min_right  Max_right  Max_right  Min_right  Min_right  \
# 4716        0.0        0.0       39.0       39.0        0.0        0.0
#
#       Max_right  Max_right      X_right      Y_right  Skew_right  Kurt_right  \
# 4716       39.0       39.0  1289.442396  1226.643925    9.757399  112.195446
#
#       RawIntDen_right  Ch_right  Frame_right  pairwise_dist
# 4716           6025.0       1.0          119       7.014769  ,       Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 4733    26269.0  34.844265       0.0       0.0     525.0     525.0       0.0
#
#       Min_left  Max_left  Max_left      X_left      Y_left  Skew_left  \
# 4733       0.0     525.0     525.0  338.782843  538.862138   2.528663
#
#       Kurt_left  RawIntDen_left  Ch_left  Frame_left                 geometry  \
# 4733   6.838675        915324.0      1.0         119  POINT (338.783 538.862)
#
#       index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 4733         4763     26524.0   35.512178        0.0        0.0      549.0
#
#       Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 4733      549.0        0.0        0.0      549.0      549.0  334.618911
#
#          Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 4733  535.781594    2.937933    9.718748         941925.0       1.0
#
#       Frame_right  pairwise_dist
# 4733          120       5.179583  ,       Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 4734    12671.0   0.727172       0.0       0.0      34.0      34.0       0.0
#
#       Min_left  Max_left  Max_left      X_left      Y_left  Skew_left  \
# 4734       0.0      34.0      34.0  483.253611  544.978731   5.002105
#
#       Kurt_left  RawIntDen_left  Ch_left  Frame_left                 geometry  \
# 4734  28.133825          9214.0      1.0         119  POINT (483.254 544.979)
#
#       index_right  Area_right  Mean_right  Min_right  Min_right  Max_right  \
# 4734         4764     18360.0     0.76585        0.0        0.0       42.0
#
#       Max_right  Min_right  Min_right  Max_right  Max_right     X_right  \
# 4734       42.0        0.0        0.0       42.0       42.0  481.973529
#
#          Y_right  Skew_right  Kurt_right  RawIntDen_right  Ch_right  \
# 4734  544.663453    5.280132   34.194986          14061.0       1.0
#
#       Frame_right  pairwise_dist
# 4734          120       1.318335  ,       Area_left  Mean_left  Min_left  Min_left  Max_left  Max_left  Min_left  \
# 4744    29703.0   0.202841       0.0       0.0      39.0      39.0       0.0
#
#       Min_left  Max_left  Max_left       X_left       Y_left  Skew_left  \
# 4744       0.0      39.0      39.0  1289.442396  1226.643925   9.757399
#
#        Kurt_left  RawIntDen_left  Ch_left  Frame_left  \
# 4744  112.195446          6025.0      1.0         119
#
#                        geometry  index_right  Area_right  Mean_right  \
# 4744  POINT (1289.442 1226.644)         4772     28637.0     0.20037
#
#       Min_right  Min_right  Max_right  Max_right  Min_right  Min_right  \
# 4744        0.0        0.0       30.0       30.0        0.0        0.0
#
#       Max_right  Max_right      X_right      Y_right  Skew_right  Kurt_right  \
# 4744       30.0       30.0  1288.306055  1227.095453    9.453993  101.437168
#
#       RawIntDen_right  Ch_right  Frame_right  pairwise_dist
# 4744           5738.0       1.0          120       1.222763  ])

# %%
showPolygonRoi = scyjava.jimport('ij.gui.PolygonRoi')
Overlay = scyjava.jimport('ij.gui.Overlay')
Regions = scyjava.jimport('net.imglib2.roi.Regions')
LabelRegions = scyjava.jimport('net.imglib2.roi.labeling.LabelRegions')
ZProjector = scyjava.jimport('ij.plugin.ZProjector')()
ov = Overlay()

# %%
def collapse_z(raw_dataset, output_files, method='sum', verbose=True):
    """Stack multiple z slices for each timepoint.

    If I understand Jacques' explanation of the quantification methods
    correctly, they sometimes (often?) perform better on the
￼
￼
￼
￼

    z-integration of pixels at each timepoint.  This function performs
    that and sends the stacked slices to the output directory and adds
    the filenames to the output_files dictionary.
    """
    cellpose_slices = list(output_files.keys())
    slice_number = 0
    collapsed_slices = []
    for slice_name in cellpose_slices:
        output_directory = os.path.dirname(output_files[slice_name]['output_txt'])
        collapsed_directory = os.path.dirname(output_directory)
        collapsed_directory = f"{collapsed_directory}/collapsed"
        os.makedirs(collapsed_directory, exist_ok=True)
        output_filename = Path(f"{collapsed_directory}/frame{slice_number}.tif").as_posix()
        output_files[slice_name]['collapsed_file'] = output_filename
        if os.path.exists(output_filename):
            if verbose:
                print(f"Skipping {output_filename}, it already exists.")
        else:
            larger_slice = raw_dataset[:, :, :, :, slice_number]
            imp = ij.py.to_imageplus(larger_slice)
            z_projector_result = ZProjector.run(imp, method)
            ## z_projector_mask = ij.IJ.run(z_projector_result, "Convert to Mask", "method=Otsu background=Light")
            z_collapsed_image = ij.py.from_java(z_projector_result)
            z_collapsed_dataset = ij.py.to_dataset(z_collapsed_image)
            saved = ij.io().save(z_collapsed_dataset, output_filename)
            if verbose:
                print(f"Saving image {output_filename}.")
        slice_number = slice_number + 1
    return output_files


def convert_slices_to_pandas(slices, verbose=False):
    """Dump the cellpose_result slice data to a single df.

    There is no good reason for me to store the data as a series of
    dataframes within a dictionary except I want to get more
    comfortable with python datastructures.  Thus, this function
    should be extraneous, but serves as a way to go from my hash to a
    single df.
    """
    concatenated = pandas.DataFrame()
    slice_keys = list(slices.keys())
    slice_counter = 0
    for k in slice_keys:
        slice_counter = slice_counter + 1
        current_slice = slices[k]
        if verbose:
            print(f"The slice is {k}")
        slice_number = current_slice['slice_number']
        slice_data = current_slice['measurements']
        slice_data['Frame'] = slice_number
        if slice_counter == 1:
            concatenated = slice_data
        else:
            concatenated = pandas.concat([concatenated, slice_data])
    ## This is a little silly, but I couldn't remember that the index attribute
    ## is the numeric rowname for a moment
    ## The reset_index() does what it says on the tine, and changes the 1:19, 1:20, etc
    ## of each individual time Frame to a single range of 1:2000
    concatenated.index = concatenated.reset_index().index
    return concatenated


def create_cellpose_rois(output_files, ij, raw_image, imp, collapsed=False, verbose=True,
                         delete = False, max_frames = 3):
    """Read the text cellpose output files, generate ROIs."""
    cellpose_slices = list(output_files.keys())
    data_info = {}
    for element in range(len(raw_image.dims)):
        name = raw_image.dims[element]
        data_info[name] = raw_image.shape[element]
    num_times = data_info['Time'] + 1
    num_channels = data_info['Channel']
    num_z = data_info['Z']

    Overlay = scyjava.jimport('ij.gui.Overlay')
    ov = Overlay()
    ## Set the initial time/Channel/Z
    time_set = imp.setT(1)
    Z_set = imp.setZ(1)
    C_set = imp.setC(1)

    rm = ij.RoiManager.getRoiManager()
    rm.runCommand("Associated", "true")
    ## rm.runCommand("show All with labels")
    slice_directory = ''
    print("Starting to iterate over times.")
    for timepoint in range(1, num_times):
        frame_number = timepoint - 1 ## I used 0-indexed for the frames.
        slice_name = f"frame_{frame_number}"
        input_tif = output_files[slice_name]['input_file']
        slice_directory_name = os.path.basename(os.path.dirname(os.path.dirname(input_tif)))
        input_txt = output_files[slice_name]['output_txt']
        input_mask = output_files[slice_name]['output_mask']
        ## The logic for this was taken from:
        ## https://stackoverflow.com/questions/73849418/is-there-any-way-to-switch-imagej-macro-code-to-python3-code
        txt_fh = open(input_txt, 'r')
        roi_stats = defaultdict(list)
        ## Now get the slice for this timepoint from the raw data
        for line in txt_fh:
            xy = line.rstrip().split(",")
            xy_coords = [int(element) for element in xy if element not in '']
            x_coords = [int(element) for element in xy[::2] if element not in '']
            y_coords = [int(element) for element in xy[1::2] if element not in '']
            xcoords_jint = JArray(JInt)(x_coords)
            ycoords_jint = JArray(JInt)(y_coords)
            polygon_roi_instance = scyjava.jimport('ij.gui.PolygonRoi')
            roi_instance = scyjava.jimport('ij.gui.Roi')
            imported_polygon = polygon_roi_instance(xcoords_jint, ycoords_jint,
                                                    len(x_coords), int(roi_instance.POLYGON))
            imp.setRoi(imported_polygon)
            added = rm.addRoi(imported_polygon)
            roi_count = rm.getCount() ## Get the current number of ROIs, 1 indexed.
            roi_count = rm.getCount()
            roi_zero_idx = roi_count - 1
            selected = rm.select(roi_zero_idx)
            time_set = imp.setT(timepoint)
            updated = rm.runCommand("Update")
            print(f"Finished time: {timepoint} ROI: {roi_count}")
        txt_fh.close()
    imp.show()
    roi_index = JArray(JInt)(range(0, rm.getCount()))
    rm.setSelectedIndexes(roi_index)
    rm.runCommand('Save', f"{slice_directory_name}.zip")
    if delete:
        rm.runCommand('Delete')
    return output_files


## Relevant options:
## batch_size(increase for more parallelization), channels(two element list of two element
## channels to segment; the first is the segment, second is optional nucleus;
## internal elements are color channels to query, so [[0,0],[2,3]] means do main cells in
## grayscale and a second with cells in blue, nuclei in green.
## channel_axis, z_axis ? invert (T/F flip pixels from b/w I assume),
## normalize(T/F percentile normalize the data), diameter, do_3d,
## anisotropy (rescaling factor for 3d segmentation), net_avg (average models),
## augment ?, tile ?, resample, interp, flow_threshold, cellprob_threshold (interesting),
## min_size (turned off with -1), stitch_threshold ?, rescale ?.
def invoke_cellpose(input_directory, model_file, channels=[[0, 0]], diameter=160,
                    threshold=0.4, do_3D=False, batch_size=64, verbose=True, gpu=True):
    """Invoke cellpose using individual slices.

    This takes the series of slices from separate_slices() and sends
    them to cellpose with a specific model.  The dictionary it returns
    is the primary datastructure for the various functions which follow.
    """

    ## Relevant options:
    ## model_type(cyto, nuclei, cyto2), net_avg(T/F if load built in networks and average them)
    model = models.CellposeModel(gpu=gpu, pretrained_model=model_file)
    slice_directory = Path(f"{input_directory}/slices").as_posix()
    files = get_image_files(slice_directory, '_masks', look_one_level_down=False)
    needed_imgs = []
    output_masks = []
    output_txts = []
    output_files = defaultdict(dict)
    existing_files = 0
    count = 0
    for one_file in files:
        print(f"Reading {one_file}")
        cp_output_directory = Path(f"{input_directory}/cellpose").as_posix()
        os.makedirs(cp_output_directory, exist_ok=True)
        f_name = os.path.basename(one_file)
        f_name = os.path.splitext(f_name)[0]
        start_mask = Path(f"{slice_directory}/{f_name}_cp_masks.png").as_posix()
        output_mask = Path(f"{cp_output_directory}/{f_name}_cp_masks.png").as_posix()
        start_txt = Path(f"{slice_directory}/{f_name}_cp_outlines.txt").as_posix()
        output_txt = Path(f"{cp_output_directory}/{f_name}_cp_outlines.txt").as_posix()
        print(f"Adding new txt file: {output_txt}")
        output_files[f_name]['input_file'] = one_file
        output_files[f_name]['start_mask'] = start_mask
        output_files[f_name]['output_mask'] = output_mask
        output_files[f_name]['start_txt'] = start_txt
        output_files[f_name]['output_txt'] = output_txt
        output_files[f_name]['exists'] = False
        if (os.path.exists(start_txt) or os.path.exists(output_txt)):
            existing_files = existing_files + 1
            print(f"This file already exists: {start_txt}")
            output_files[f_name]['exists'] = True
        else:
            print(f"This file does not exist: {start_txt}")
            img = imread(one_file)
            needed_imgs.append(img)
        count = count + 1
    nimg = len(needed_imgs)
    if verbose and nimg > 0:
        print(f"Reading {nimg} images, starting cellpose.")
        masks, flows, styles = model.eval(needed_imgs, diameter=diameter,
                                          channels=channels, flow_threshold=threshold,
                                          do_3D=do_3D, batch_size=batch_size)
        saved = io.save_to_png(needed_imgs, masks, flows, files)
    else:
        print("Returning the output files.")
    return output_files


def move_cellpose_output(output_files, verbose=False):
    """Cellpose puts its output files into the cwd, I want them in specific directories."""
    print(f"Moving cellpose outputs to the cellpose output directory.")
    output_filenames = list(output_files.keys())
    for f_name in output_filenames:
        output_file = output_files[f_name]['output_mask']
        if (os.path.exists(output_file)):
            if verbose:
                print("The output already exists.")
        else:
            if verbose:
                print(f"Moving {output_files[f_name]['start_mask']} to {output_file}")
            mask_moved = shutil.move(output_files[f_name]['start_mask'],
                                     output_files[f_name]['output_mask'])
            txt_moved = shutil.move(output_files[f_name]['start_txt'],
                                    output_files[f_name]['output_txt'])


def nearest_cells_over_time(df, max_dist=100.0, max_prop=None, x_column='X',
                            y_column='Y', verbose=True):
    """Trace cells over time

    If I understand Jacques' goals correctly, the tracing of cells
    over time should be a reasonably tractable problem for the various
    geo-statistics tools to handle; their whole purpose is to
    calculate n-dimensional distances.  So, let us pass my df to one
    of them and see what happens!

    Upon completion, we should get an array(dictionary? I forget) of
    arrays where each primary key is the top-level cell ID.  Each
    internal array is the set of IDs from the geopandas dataframe,
    which contains all of the measurements.  Thus, we can easily
    extract the data for individual cells and play with it.
    """
    gdf = geopandas.GeoDataFrame(
        df, geometry=geopandas.points_from_xy(df[x_column], df[y_column]))

    final_time = gdf.Frame.max()
    pairwise_distances = []
    for start_time in range(0, final_time):
        i = start_time
        j = i + 1
        ti_idx = gdf.Frame == i
        tj_idx = gdf.Frame == j
        if verbose:
            print(f"Getting distances of dfs {i} and {j}.")
        ti = gdf[ti_idx]
        tj = gdf[tj_idx]
        ti_rows = ti.shape[0]
        tj_rows = tj.shape[0]
        for ti_row in range(0, ti_rows):
            ti_element = ti.iloc[[ti_row, ]]
            titj = geopandas.sjoin_nearest(ti_element, tj, distance_col="pairwise_dist",
                                           max_distance=max_dist)
            chosen_closest_dist = titj.pairwise_dist.min()
            if (isnan(chosen_closest_dist)):
                print(f"This element has no neighbor within {max_dist}.")
            else:
                chosen_closest_cell = titj.pairwise_dist == chosen_closest_dist
                chosen_closest_row = titj[chosen_closest_cell]
                pairwise_distances.append(chosen_closest_row)

    paired = pandas.concat(pairwise_distances)
    id_counter = 0
    ## Cell IDs pointing to a list of cells
    traced = {}
    ## Endpoints pointing to the cell IDs
    ends = {}
    for i in range(0, final_time - 1):
        query_idx = paired.Frame_left == i
        query = paired[query_idx]
        for row in query.itertuples():
            start_cell = row.Index
            end_cell = row.index_right
            if start_cell in ends.keys():
                cell_id = ends[start_cell]
                current_value = traced[cell_id]
                current_value.append(end_cell)
                traced[cell_id] = current_value
                ends[end_cell] = cell_id
            else:
                id_counter = id_counter + 1
                traced[id_counter] = [start_cell, end_cell]
                ends[end_cell] = id_counter
    return traced, paired, pairwise_distances


def separate_slices(input_file, ij, wanted_x=True, wanted_y=True, wanted_z=1,
    wanted_channel=2, cpus=8, overwrite=False, verbose=True):
    """Slice an image in preparation for cellpose.

    Eventually this should be smart enough to handle arbitrary
    x,y,z,channels,times as well as able to use multiple cpus for
    saving the data.  In its current implementation, it only saves 1
    z, 1 channel for every frame of an image into a series of files in
    its output directory.
    """

    input_base = os.path.basename(input_file)
    input_dir = os.path.dirname(input_file)
    input_name = os.path.splitext(input_base)[0]
    output_directory = Path(f"{input_dir}/outputs/{input_name}_z{wanted_z}").as_posix()
    slice_directory = Path(f"{output_directory}/slices").as_posix()
    os.makedirs(output_directory, exist_ok=True)
    os.makedirs(slice_directory, exist_ok=True)
    if verbose:
        print("Starting to open the input file, this takes a moment.")
    raw_dataset = ij.io().open(input_file)
    if verbose:
        print(f"Opened input file, writing images to {output_directory}")

    data_info = {}
    for element in range(len(raw_dataset.dims)):
        name = raw_dataset.dims[element]
        data_info[name] = raw_dataset.shape[element]
    if verbose:
        print(
            f"This dataset has dimensions: X:{data_info['X']}",
            f"Y:{data_info['Y']} Z:{data_info['Z']} Time:{data_info['Time']}",
        )

    slices = []
    for timepoint in range(data_info['Time']):
        wanted_slice = raw_dataset[:, :, wanted_channel, wanted_z, timepoint]
        slice_data = ij.py.to_dataset(wanted_slice)
        output_filename = Path(f"{output_directory}/slices/frame_{timepoint}.tif").as_posix()
        if os.path.exists(output_filename):
            if overwrite:
                print(f"Rewriting {output_filename}")
                os.remove(output_filename)
                saved = ij.io().save(slice_data, output_filename)
            else:
                if verbose:
                    print(f"Skipping {output_filename}, it already exists.")
        else:
            saved = ij.io().save(slice_data, output_filename)
            if verbose:
                print(f"Saving image {input_name}_{timepoint}.")
        slices.append(wanted_slice)
    print(f"Returning the output directory: {output_directory}")
    return raw_dataset, slices, output_directory


## The following is from a mix of a couple of implementations I found:
## https://pyimagej.readthedocs.io/en/latest/Classic-Segmentation.html
## an alternative method may be taken from:
## https://pyimagej.readthedocs.io/en/latest/Classic-Segmentation.html#segmentation-workflow-with-imagej2
## My goal is to pass the ROI regions to this function and create a similar df.
def slices_to_roi_measurements(cellpose_result, ij, collapsed=False, verbose=True):
    """Read the text cellpose output files, generate ROIs, and measure.

    I think there are better ways of accomplishing this task than
    using ij.IJ.run(); but this seems to work...  Upon completion,
    this function should add a series of dataframes to the
    cellpose_result dictionary which comprise the various metrics from
    ImageJ's measurement function of the ROIs detected by cellpose.
    """

    showPolygonRoi = scyjava.jimport('ij.gui.PolygonRoi')
    Overlay = scyjava.jimport('ij.gui.Overlay')
    Regions = scyjava.jimport('net.imglib2.roi.Regions')
    LabelRegions = scyjava.jimport('net.imglib2.roi.labeling.LabelRegions')
    ZProjector = scyjava.jimport('ij.plugin.ZProjector')()
    ov = Overlay()

    output_dict = cellpose_result
    cellpose_slices = list(cellpose_result.keys())
    slice_number = 0
    for slice_name in cellpose_slices:
        output_dict[slice_name]['slice_number'] = slice_number
        input_tif = ''
        if collapsed:
            input_tif = cellpose_result[slice_name]['collapsed_file']
        else:
            input_tif = cellpose_result[slice_name]['input_file']
        slice_dataset = ij.io().open(input_tif)
        slice_data = ij.py.to_imageplus(slice_dataset)
        input_txt = cellpose_result[slice_name]['output_txt']
        input_mask = cellpose_result[slice_name]['output_mask']
        if verbose:
            print(f"Processing cellpose outline: {input_txt}")
            print(f"Measuring: {input_tif}")
        # convert Dataset to ImagePlus
        imp = ij.py.to_imageplus(slice_data)
        rm = ij.RoiManager.getRoiManager()
        rm.runCommand("Associated", "true")
        rm.runCommand("show All with labels")
        ## The logic for this was taken from:
        ## https://stackoverflow.com/questions/73849418/is-there-any-way-to-switch-imagej-macro-code-to-python3-code
        txt_fh = open(input_txt, 'r')
        set_string = f'Set Measurements...'
        measure_string = f'area mean min centroid median skewness kurtosis integrated stack redirect=None decimal=3'
        ij.IJ.run(set_string, measure_string)
        roi_stats = defaultdict(list)
        for line in txt_fh:
            xy = line.rstrip().split(",")
            xy_coords = [int(element) for element in xy if element not in '']
            x_coords = [int(element) for element in xy[::2] if element not in '']
            y_coords = [int(element) for element in xy[1::2] if element not in '']
            xcoords_jint = JArray(JInt)(x_coords)
            ycoords_jint = JArray(JInt)(y_coords)
            polygon_roi_instance = scyjava.jimport('ij.gui.PolygonRoi')
            roi_instance = scyjava.jimport('ij.gui.Roi')
            imported_polygon = polygon_roi_instance(
                xcoords_jint, ycoords_jint, len(x_coords), int(roi_instance.POLYGON)
            )
            imp.setRoi(imported_polygon)
            rm.addRoi(imported_polygon)
            ij.IJ.run(imp, 'Measure', '')
        ## rm.runCommand('Update')  ## I think the update command needs an open image to function.
        slice_result = ij.ResultsTable.getResultsTable()
        slice_table = ij.convert().convert(
            slice_result, scyjava.jimport('org.scijava.table.Table')
        )
        slice_measurements = ij.py.from_java(slice_table)
        output_dict[slice_name]['measurements'] = slice_measurements
        ij.IJ.run('Clear Results')
        txt_fh.close()
        imp.setOverlay(ov)
        imp.getProcessor().resetMinAndMax()
        slice_number = slice_number + 1
    return output_dict

# %%
raw_dataset, saved_slices, output_directory = separate_slices(input_file, ij, wanted_z = 2,
                                                              wanted_channel = 3)
# Out:
# [java.lang.Enum.toString] ZeissCZIReader initializing /home/saka/Documents/Lab stuff/confocal/exp2/Experiment-1647-Split Scenes-01.czi
# [WARN] Unknown DetectorType value 'GaAsP-PMT' will be stored as "Other"
# [java.lang.Enum.toString] [WARN] Unknown DetectorType value 'GaAsP-PMT' will be stored as "Other"
# [WARN] Unknown DetectorType value 'GaAsP-PMT' will be stored as "Other"
# [java.lang.Enum.toString] [WARN] Unknown DetectorType value 'GaAsP-PMT' will be stored as "Other"
# [WARN] Unknown DetectorType value 'GaAsP-PMT' will be stored as "Other"
# [java.lang.Enum.toString] [WARN] Unknown DetectorType value 'GaAsP-PMT' will be stored as "Other"
# [WARN] Unknown DetectorType value 'Multialkali-PMT' will be stored as "Other"
# [java.lang.Enum.toString] [WARN] Unknown DetectorType value 'Multialkali-PMT' will be stored as "Other"

# %%
output_files = invoke_cellpose(output_directory, '/home/saka/Documents/CP_20220523_104016')

# %%
move_cellpose_output(output_files)

# %%
output_files = collapse_z(raw_dataset, output_files)

# %%
slice_measurements = slices_to_roi_measurements(output_files, ij, collapsed = True)

# %%
updated = create_cellpose_rois(output_files, raw_image, collapsed = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 updated = create_cellpose_rois(output_files, raw_image, collapsed = True)
#
# TypeError: create_cellpose_rois() missing 2 required positional arguments: 'raw_image' and 'imp'

# %%
concatenated = convert_slices_to_pandas(slice_measurements)

# %%
nearest = nearest_cells_over_time(concatenated, max_dist = 10.0,
                                  x_column = 'X', y_column = 'Y')

# %%
cell_id = 291
cell_idx = nearest[cell_id]
cell_data = concatenated.loc[cell_idx]
len(cell_data)
# Out:
# 4

# %%
cell_data = cell_data.reset_index()

scatter = plt.scatter(cell_data['X'], cell_data['Y'])
final_row = cell_data.index.max()
for start_time in range(0, final_row - 1):
    ti_idx = cell_data.index == start_time
    tj_idx = cell_data.index == start_time + 1
    p1x = cell_data[ti_idx].X
    p2x = cell_data[tj_idx].X
    p1y = cell_data[ti_idx].Y
    p2y = cell_data[tj_idx].Y
    x_points = [p1x, p2x]
    y_points = [p1y, p2y]
    plt.plot(x_points, y_points)
finalm1_idx = cell_data.index == final_row - 1
final_idx = cell_data.index == final_row
finalm1_x = cell_data[finalm1_idx].X
final_x = cell_data[final_idx].X
finalm1_y = cell_data[finalm1_idx].Y
final_y = cell_data[final_idx].Y
x_points = [finalm1_x, final_x]
y_points = [finalm1_y, final_y]
plt.plot(x_points, y_points)
plt.show()

# %%
seaborn.violinplot(data = cell_data.Area)
plt.show()

# %% [markdown]
# ## Test Area

# %%
raw_image = ij.io().open('/home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/MAX_slices.tif')
#raw_image = ij.io().open(input_file)
shown = ij.ui().show(raw_image)
imp = ij.py.to_imageplus(raw_image)

# %%
rm = ij.RoiManager.getRoiManager()

# %%
import random
colors = ["black", "blue", "cyan", "green", "magenta", "orange", "red", "white", "yellow"]

cell_id = nearest.keys()
for i in cell_id :
    cell_idx = nearest[i]
    random_color = random.choice(colors)
    #cell_data = concatenated.loc[cell_idx]
# Iterate over the cell_idx values
    for idx in cell_idx:
        # Get the ROI from the ROI Manager 
        roi = rm.select(idx - 1)
        overlay_command = f"Overlay.addSelection('{random_color}', 5);"
        # Add the ROI to the array
        ij.py.run_macro(overlay_command)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 4
#       1 import random
#       2 colors = ["black", "blue", "cyan", "green", "magenta", "orange", "red", "white", "yellow"]
# ----> 4 cell_id = nearest.keys()
#       5 for i in cell_id :
#       6     cell_idx = nearest[i]
#
# AttributeError: 'tuple' object has no attribute 'keys'

# %%
prout = nearest[3] + nearest[47] + nearest[75] + nearest[117]      #this works to concatenate different cell ids.

# %%
print(paired)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(paired)
#
# NameError: name 'paired' is not defined

# %%
for idx in prout:
    roi = rm.select(idx - 1)
    overlay_command = f"Overlay.addSelection('Red',5);"
    ij.py.run_macro(overlay_command)
