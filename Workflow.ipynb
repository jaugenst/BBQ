# %%
from cellpose import models, io
from cellpose.io import *
from collections import defaultdict
import geopandas
import glob
import imagej
from jpype import JArray, JInt
import matplotlib.pyplot as plt
import multiprocessing as mp
import numpy as np
import os
import pandas
from pandas import DataFrame
from pathlib import Path
import scyjava
import seaborn
import shutil

# %%
base_dir = '/home/saka/Documents/Lab stuff/confocal/exp2'
os.chdir(base_dir)
input_file = Path(f"{base_dir}/Experiment-1647-Split Scenes-01.czi").as_posix()
pandas.set_option('display.max_columns', None)
verbose = True

# %%
def start_fiji(base=None, mem='-Xmx30g', location='/home/saka/sw/local/fiji/2023', mode='interactive', input_file=None):
    scyjava.config.add_option(mem)
    start_dir = os.getcwd()
    if base:
        start_dir = base
    print(f"Where am I: {start_dir}")
    ij = imagej.init(Path(location), mode=mode)
    ij.getApp().getInfo(True)
    ij.ui().showUI()
    ## Something about this init() function changes the current working directory.
    os.chdir(start_dir)
    ij.getVersion()
    raw_image = None
    imp = None
    if input_file:
        raw_image = ij.io().open(input_file)
        shown = ij.ui().show(raw_image)
        imp = ij.py.to_imageplus(raw_image)
    return ij, raw_image, imp

# %%
scyjava.config.add_option('-Xmx30g')
start_dir = os.getcwd()
#ij = imagej.init('sc.fiji:fiji', mode='interactive')
ij = imagej.init('/home/saka/sw/local/fiji/2023', mode='interactive')
## Something about this init() function changes the current working directory.
ij.getApp().getInfo(True)
ij.ui().showUI()
os.chdir(start_dir)
ij.getVersion()
# Out:
# '2.9.0/1.54e'
# Starting to open the input file, this takes a moment.
# ZeissCZIReader initializing /home/saka/Documents/Lab stuff/confocal/exp2/Experiment-1647-Split Scenes-01.czi
# Opened input file, writing images to /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2
# This dataset has dimensions: X:2048 Y:2048 Z:11 Time:121
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_0.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_1.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_2.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_3.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_4.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_5.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_6.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_7.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_8.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_9.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_10.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_11.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_12.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_13.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_14.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_15.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_16.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_17.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_18.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_19.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_20.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_21.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_22.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_23.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_24.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_25.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_26.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_27.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_28.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_29.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_30.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_31.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_32.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_33.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_34.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_35.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_36.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_37.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_38.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_39.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_40.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_41.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_42.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_43.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_44.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_45.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_46.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_47.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_48.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_49.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_50.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_51.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_52.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_53.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_54.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_55.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_56.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_57.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_58.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_59.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_60.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_61.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_62.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_63.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_64.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_65.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_66.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_67.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_68.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_69.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_70.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_71.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_72.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_73.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_74.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_75.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_76.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_77.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_78.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_79.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_80.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_81.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_82.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_83.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_84.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_85.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_86.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_87.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_88.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_89.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_90.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_91.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_92.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_93.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_94.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_95.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_96.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_97.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_98.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_99.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_100.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_101.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_102.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_103.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_104.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_105.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_106.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_107.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_108.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_109.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_110.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_111.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_112.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_113.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_114.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_115.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_116.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_117.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_118.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_119.tif, it already exists.
# Skipping /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_120.tif, it already exists.
# Returning the output directory: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_0.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_0_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_0_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_1.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_1_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_1_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_2.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_2_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_2_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_3.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_3_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_3_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_4.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_4_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_4_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_5.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_5_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_5_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_6.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_6_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_6_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_7.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_7_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_7_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_8.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_8_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_8_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_9.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_9_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_9_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_10.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_10_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_10_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_11.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_11_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_11_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_12.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_12_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_12_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_13.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_13_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_13_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_14.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_14_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_14_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_15.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_15_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_15_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_16.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_16_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_16_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_17.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_17_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_17_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_18.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_18_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_18_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_19.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_19_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_19_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_20.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_20_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_20_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_21.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_21_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_21_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_22.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_22_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_22_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_23.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_23_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_23_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_24.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_24_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_24_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_25.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_25_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_25_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_26.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_26_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_26_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_27.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_27_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_27_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_28.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_28_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_28_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_29.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_29_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_29_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_30.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_30_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_30_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_31.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_31_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_31_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_32.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_32_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_32_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_33.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_33_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_33_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_34.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_34_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_34_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_35.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_35_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_35_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_36.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_36_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_36_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_37.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_37_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_37_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_38.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_38_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_38_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_39.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_39_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_39_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_40.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_40_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_40_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_41.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_41_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_41_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_42.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_42_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_42_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_43.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_43_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_43_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_44.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_44_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_44_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_45.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_45_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_45_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_46.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_46_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_46_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_47.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_47_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_47_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_48.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_48_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_48_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_49.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_49_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_49_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_50.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_50_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_50_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_51.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_51_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_51_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_52.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_52_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_52_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_53.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_53_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_53_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_54.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_54_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_54_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_55.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_55_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_55_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_56.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_56_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_56_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_57.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_57_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_57_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_58.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_58_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_58_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_59.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_59_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_59_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_60.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_60_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_60_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_61.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_61_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_61_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_62.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_62_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_62_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_63.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_63_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_63_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_64.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_64_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_64_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_65.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_65_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_65_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_66.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_66_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_66_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_67.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_67_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_67_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_68.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_68_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_68_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_69.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_69_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_69_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_70.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_70_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_70_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_71.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_71_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_71_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_72.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_72_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_72_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_73.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_73_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_73_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_74.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_74_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_74_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_75.tif
# Adding new txt file: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_75_cp_outlines.txt
# This file already exists: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_75_cp_outlines.txt
# Reading /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/slices/frame_76.tif
# ...
# Measuring: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/collapsed/frame115.tif
# Processing cellpose outline: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_116_cp_outlines.txt
# Measuring: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/collapsed/frame116.tif
# Processing cellpose outline: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_117_cp_outlines.txt
# Measuring: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/collapsed/frame117.tif
# Processing cellpose outline: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_118_cp_outlines.txt
# Measuring: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/collapsed/frame118.tif
# Processing cellpose outline: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_119_cp_outlines.txt
# Measuring: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/collapsed/frame119.tif
# Processing cellpose outline: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/cellpose/frame_120_cp_outlines.txt
# Measuring: /home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/collapsed/frame120.tif
# Getting distances of dfs 1 and 2.
# Getting distances of dfs 2 and 3.
# Getting distances of dfs 3 and 4.
# Getting distances of dfs 4 and 5.
# Getting distances of dfs 5 and 6.
# Getting distances of dfs 6 and 7.
# Getting distances of dfs 7 and 8.
# Getting distances of dfs 8 and 9.
# Getting distances of dfs 9 and 10.
# Getting distances of dfs 10 and 11.
# Getting distances of dfs 11 and 12.
# Getting distances of dfs 12 and 13.
# Getting distances of dfs 13 and 14.
# Getting distances of dfs 14 and 15.
# Getting distances of dfs 15 and 16.
# Getting distances of dfs 16 and 17.
# Getting distances of dfs 17 and 18.
# Getting distances of dfs 18 and 19.
# Getting distances of dfs 19 and 20.
# Getting distances of dfs 20 and 21.
# Getting distances of dfs 21 and 22.
# Getting distances of dfs 22 and 23.
# Getting distances of dfs 23 and 24.
# Getting distances of dfs 24 and 25.
# Getting distances of dfs 25 and 26.
# Getting distances of dfs 26 and 27.
# Getting distances of dfs 27 and 28.
# Getting distances of dfs 28 and 29.
# Getting distances of dfs 29 and 30.
# Getting distances of dfs 30 and 31.
# Getting distances of dfs 31 and 32.
# Getting distances of dfs 32 and 33.
# Getting distances of dfs 33 and 34.
# Getting distances of dfs 34 and 35.
# Getting distances of dfs 35 and 36.
# Getting distances of dfs 36 and 37.
# Getting distances of dfs 37 and 38.
# Getting distances of dfs 38 and 39.
# Getting distances of dfs 39 and 40.
# Getting distances of dfs 40 and 41.
# Getting distances of dfs 41 and 42.
# Getting distances of dfs 42 and 43.
# Getting distances of dfs 43 and 44.
# Getting distances of dfs 44 and 45.
# Getting distances of dfs 45 and 46.
# Getting distances of dfs 46 and 47.
# Getting distances of dfs 47 and 48.
# Getting distances of dfs 48 and 49.
# Getting distances of dfs 49 and 50.
# Getting distances of dfs 50 and 51.
# Getting distances of dfs 51 and 52.
# Getting distances of dfs 52 and 53.
# Getting distances of dfs 53 and 54.
# Getting distances of dfs 54 and 55.
# Getting distances of dfs 55 and 56.
# Getting distances of dfs 56 and 57.
# Getting distances of dfs 57 and 58.
# Getting distances of dfs 58 and 59.
# Getting distances of dfs 59 and 60.
# Getting distances of dfs 60 and 61.
# Getting distances of dfs 61 and 62.
# Getting distances of dfs 62 and 63.
# Getting distances of dfs 63 and 64.
# Getting distances of dfs 64 and 65.
# Getting distances of dfs 65 and 66.
# Getting distances of dfs 66 and 67.
# Getting distances of dfs 67 and 68.
# Getting distances of dfs 68 and 69.
# Getting distances of dfs 69 and 70.
# Getting distances of dfs 70 and 71.
# Getting distances of dfs 71 and 72.
# Getting distances of dfs 72 and 73.
# Getting distances of dfs 73 and 74.
# Getting distances of dfs 74 and 75.
# Getting distances of dfs 75 and 76.
# Getting distances of dfs 76 and 77.
# Getting distances of dfs 77 and 78.
# Getting distances of dfs 78 and 79.
# Getting distances of dfs 79 and 80.
# Getting distances of dfs 80 and 81.
# Getting distances of dfs 81 and 82.
# Getting distances of dfs 82 and 83.
# Getting distances of dfs 83 and 84.
# Getting distances of dfs 84 and 85.
# Getting distances of dfs 85 and 86.
# Getting distances of dfs 86 and 87.
# Getting distances of dfs 87 and 88.
# Getting distances of dfs 88 and 89.
# Getting distances of dfs 89 and 90.
# Getting distances of dfs 90 and 91.
# Getting distances of dfs 91 and 92.
# Getting distances of dfs 92 and 93.
# Getting distances of dfs 93 and 94.
# Getting distances of dfs 94 and 95.
# Getting distances of dfs 95 and 96.
# Getting distances of dfs 96 and 97.
# Getting distances of dfs 97 and 98.
# Getting distances of dfs 98 and 99.
# Getting distances of dfs 99 and 100.
# Getting distances of dfs 100 and 101.
# Getting distances of dfs 101 and 102.
# Getting distances of dfs 102 and 103.
# Getting distances of dfs 103 and 104.
# Getting distances of dfs 104 and 105.
# Getting distances of dfs 105 and 106.
# Getting distances of dfs 106 and 107.
# Getting distances of dfs 107 and 108.
# Getting distances of dfs 108 and 109.
# Getting distances of dfs 109 and 110.
# Getting distances of dfs 110 and 111.
# Getting distances of dfs 111 and 112.
# Getting distances of dfs 112 and 113.
# Getting distances of dfs 113 and 114.
# Getting distances of dfs 114 and 115.
# Getting distances of dfs 115 and 116.
# Getting distances of dfs 116 and 117.
# Getting distances of dfs 117 and 118.
# Getting distances of dfs 118 and 119.
# Getting distances of dfs 119 and 120.
# Skipped 38 elements in segment 0.
# Skipped 35 elements in segment 1.
# Skipped 35 elements in segment 2.
# Skipped 34 elements in segment 3.
# Skipped 34 elements in segment 4.
# Skipped 33 elements in segment 5.
# Skipped 24 elements in segment 6.
# Skipped 31 elements in segment 7.
# Skipped 27 elements in segment 8.
# Skipped 31 elements in segment 9.
# Skipped 30 elements in segment 10.
# Skipped 31 elements in segment 11.
# Skipped 25 elements in segment 12.
# Skipped 31 elements in segment 13.
# Skipped 26 elements in segment 14.
# Skipped 26 elements in segment 15.
# Skipped 24 elements in segment 16.
# Skipped 23 elements in segment 17.
# Skipped 28 elements in segment 18.
# Skipped 24 elements in segment 19.
# Skipped 21 elements in segment 20.
# Skipped 20 elements in segment 21.
# Skipped 27 elements in segment 22.
# Skipped 20 elements in segment 23.
# Skipped 20 elements in segment 24.
# Skipped 22 elements in segment 25.
# Skipped 20 elements in segment 26.
# Skipped 21 elements in segment 27.
# Skipped 17 elements in segment 28.
# Skipped 23 elements in segment 29.
# Skipped 21 elements in segment 30.
# Skipped 22 elements in segment 31.
# Skipped 21 elements in segment 32.
# Skipped 26 elements in segment 33.
# Skipped 25 elements in segment 34.
# Skipped 32 elements in segment 35.
# Skipped 25 elements in segment 36.
# Skipped 25 elements in segment 37.
# Skipped 25 elements in segment 38.
# Skipped 21 elements in segment 39.
# Skipped 25 elements in segment 40.
# Skipped 30 elements in segment 41.
# Skipped 20 elements in segment 42.
# Skipped 15 elements in segment 43.
# Skipped 18 elements in segment 44.
# Skipped 16 elements in segment 45.
# Skipped 20 elements in segment 46.
# Skipped 22 elements in segment 47.
# Skipped 19 elements in segment 48.
# Skipped 23 elements in segment 49.
# Skipped 21 elements in segment 50.
# Skipped 17 elements in segment 51.
# Skipped 19 elements in segment 52.
# Skipped 20 elements in segment 53.
# Skipped 23 elements in segment 54.
# Skipped 17 elements in segment 55.
# Skipped 21 elements in segment 56.
# Skipped 31 elements in segment 57.
# Skipped 27 elements in segment 58.
# Skipped 26 elements in segment 59.
# Skipped 20 elements in segment 60.
# Skipped 21 elements in segment 61.
# Skipped 24 elements in segment 62.
# Skipped 23 elements in segment 63.
# Skipped 24 elements in segment 64.
# Skipped 28 elements in segment 65.
# Skipped 29 elements in segment 66.
# Skipped 29 elements in segment 67.
# Skipped 28 elements in segment 68.
# Skipped 28 elements in segment 69.
# Skipped 29 elements in segment 70.
# Skipped 32 elements in segment 71.
# Skipped 26 elements in segment 72.
# Skipped 21 elements in segment 73.
# Skipped 22 elements in segment 74.
# Skipped 23 elements in segment 75.
# Skipped 28 elements in segment 76.
# Skipped 22 elements in segment 77.
# Skipped 22 elements in segment 78.
# Skipped 18 elements in segment 79.
# Skipped 19 elements in segment 80.
# Skipped 28 elements in segment 81.
# Skipped 26 elements in segment 82.
# Skipped 21 elements in segment 83.
# Skipped 24 elements in segment 84.
# Skipped 26 elements in segment 85.
# Skipped 21 elements in segment 86.
# Skipped 29 elements in segment 87.
# Skipped 20 elements in segment 88.
# Skipped 16 elements in segment 89.
# Skipped 19 elements in segment 90.
# Skipped 17 elements in segment 91.
# Skipped 21 elements in segment 92.
# Skipped 22 elements in segment 93.
# Skipped 15 elements in segment 94.
# Skipped 12 elements in segment 95.
# Skipped 15 elements in segment 96.
# Skipped 19 elements in segment 97.
# Skipped 19 elements in segment 98.
# Skipped 19 elements in segment 99.
# Skipped 20 elements in segment 100.
# Skipped 21 elements in segment 101.
# Skipped 19 elements in segment 102.
# Skipped 14 elements in segment 103.
# Skipped 23 elements in segment 104.
# Skipped 19 elements in segment 105.
# Skipped 19 elements in segment 106.
# Skipped 19 elements in segment 107.
# Skipped 18 elements in segment 108.
# Skipped 16 elements in segment 109.
# Skipped 19 elements in segment 110.
# Skipped 18 elements in segment 111.
# Skipped 21 elements in segment 112.
# Skipped 21 elements in segment 113.
# Skipped 24 elements in segment 114.
# Skipped 19 elements in segment 115.
# Skipped 20 elements in segment 116.
# Skipped 14 elements in segment 117.
# Skipped 23 elements in segment 118.
# {1: [60, 115, 166], 2: [63, 119], 3: [64, 120, 171, 228], 4: [66, 122], 5: [67, 123, 175, 232, 286, 339, 390, 435, 482, 528, 580, 635, 690, 743, 797, 851], 6: [68, 124], 7: [69, 125], 8: [70, 126, 179, 237], 9: [72, 128], 10: [74, 132, 185, 240, 295, 347, 397, 440, 488, 536, 586, 645, 697, 750, 804], 11: [79, 134], 12: [81, 136, 189], 13: [82, 137, 190, 245, 299, 353], 14: [102, 155, 209, 261, 317, 368, 416, 463, 509, 558, 611, 667, 720, 775], 15: [103, 158, 211, 265, 320, 370], 16: [104, 157, 210], 17: [105, 159], 18: [106, 160], 19: [110, 163, 219, 272, 327], 20: [116, 167], 21: [141, 194, 250, 303], 22: [144, 198], 23: [153, 206], 24: [161, 216, 270], 25: [162, 217], 26: [164, 220], 27: [168, 225], 28: [170, 227, 280, 335, 386, 430, 477, 524, 573, 628, 684, 734, 789, 842, 895], 29: [172, 229], 30: [177, 234, 289, 342], 31: [181, 238], 32: [191, 248], 33: [195, 249], 34: [196, 251], 35: [197, 252], 36: [213, 266], 37: [226, 279], 38: [231, 285, 340], 39: [233, 287, 341], 40: [235, 293, 343], 41: [236, 290], 42: [243, 296, 350, 398], 43: [244, 298], 44: [259, 313], 45: [264, 318, 369, 418, 464, 511, 559], 46: [271, 325], 47: [281, 336, 387, 431, 479], 48: [282, 337, 388], 49: [291, 344, 393], 50: [292, 345, 394, 437, 486], 51: [297, 352, 401], 52: [300, 354, 403, 447], 53: [304, 356, 407, 452, 498, 548], 54: [321, 372, 419, 466, 513, 561, 614, 671, 723, 777, 828, 881, 933, 980, 1032, 1085, 1135, 1183, 1234, 1284, 1329, 1373, 1418, 1463, 1509], 55: [324, 374], 56: [332, 384], 57: [333, 385], 58: [351, 399], 59: [361, 408, 454, 501], 60: [365, 412, 458], 61: [389, 434], 62: [396, 441], 63: [404, 448, 496, 544], 64: [411, 457], 65: [415, 461], 66: [417, 465, 510, 560, 612, 670, 721, 776], 67: [420, 467], 68: [421, 468, 516, 564, 615, 674, 725], 69: [424, 471], 70: [425, 473], 71: [438, 485, 533], 72: [444, 493], 73: [459, 507], 74: [475, 523], 75: [478, 525, 576], 76: [484, 532], 77: [489, 537, 588], 78: [494, 543, 595], 79: [503, 554], 80: [515, 563], 81: [518, 565], 82: [519, 567, 618], 83: [520, 568, 620, 677, 729, 783, 834], 84: [526, 574, 629, 685, 737, 792, 844, 897, 947, 996, 1045, 1100, 1149, 1197, 1248, 1296, 1341, 1384, 1431], 85: [527, 579, 634, 688], 86: [538, 590, 648], 87: [540, 591], 88: [566, 619, 676, 727, 784, 835, 888, 939], 89: [571, 624, 680, 731, 786, 838, 892, 941], 90: [572, 626], 91: [575, 631], 92: [577, 630], 93: [578, 633, 686, 738, 793], 94: [581, 638, 692], 95: [584, 640, 695, 745, 802, 853, 906], 96: [593, 650, 702, 754], 97: [600, 656], 98: [605, 662], 99: [610, 665, 717, 771, 823, 876, 929, 978, 1028], 100: [632, 687, 739, 794, 845], 101: [636, 689], 102: [637, 691], 103: [651, 703, 755, 809, 861, 914, 963, 1013, 1064, 1116, 1165, 1215, 1266, 1313, 1358, 1401, 1445, 1490, 1537, 1585, 1634, 1674, 1721, 1761, 1806], 104: [663, 715, 767, 820], 105: [664, 716], 106: [668, 722], 107: [672, 724, 780], 108: [678, 730, 785], 109: [682, 733, 790, 841, 893, 945, 993, 1043], 110: [693, 746, 803, 854, 908, 956, 1005, 1056, 1109, 1158, 1208, 1257], 111: [694, 748], 112: [700, 753], 113: [706, 759, 812, 863, 917], 114: [707, 760], 115: [713, 766], 116: [719, 773], 117: [735, 788, 840], 118: [751, 806], 119: [752, 807], 120: [756, 810], 121: [761, 815], 122: [779, 831, 884, 935, 984, 1034, 1087, 1138, 1186], 123: [791, 843], 124: [796, 847, 900], 125: [805, 858, 911], 126: [808, 860], 127: [813, 866], 128: [814, 867, 919], 129: [819, 871, 924], 130: [821, 873], 131: [826, 878, 931, 979, 1030, 1082], 132: [832, 886], 133: [836, 889, 940, 987], 134: [848, 901, 950, 1000, 1051, 1103, 1153], 135: [852, 904, 953, 1001], 136: [856, 909, 958, 1008, 1059, 1111, 1160, 1210, 1260, 1307, 1352, 1395, 1441, 1486, 1533], 137: [865, 916, 965], 138: [869, 921], 139: [874, 927, 976, 1024, 1077, 1129, 1178], 140: [880, 932, 981], 141: [882, 936, 983], 142: [887, 938, 986], 143: [898, 948], 144: [899, 949, 999, 1048, 1102, 1152], 145: [903, 952, 1002, 1052, 1104, 1154, 1205, 1256, 1303, 1348, 1392, 1437, 1484], 146: [907, 957, 10 ...
#          Area       Mean  Min    Max  Min    Max            X            Y  \
# 0     13659.0   0.475803  0.0   35.0  0.0   35.0  1060.739915    52.916209
# 1     25583.0   0.786342  0.0   73.0  0.0   73.0  1924.707208   108.645605
# 2     26249.0   0.341499  0.0   37.0  0.0   37.0  1832.068174   209.681645
# 3     37649.0   1.679726  0.0  117.0  0.0  117.0  1443.338322   271.221613
# 4     12776.0   4.003131  0.0   63.0  0.0   63.0  1711.011271   213.684956
# ...       ...        ...  ...    ...  ...    ...          ...          ...
# 4779  16534.0  14.388593  0.0  126.0  0.0  126.0   305.072699  1927.624713
# 4780  26540.0   0.121891  0.0   35.0  0.0   35.0  1919.232366  1981.046910
# 4781  17651.0   3.514475  0.0   56.0  0.0   56.0  1415.496487  1963.454280
# 4782  15020.0  10.034421  0.0  256.0  0.0  256.0   744.047137  1997.295073
# 4783  16582.0   1.224521  0.0   64.0  0.0   64.0   482.141298  1999.206067
#
#            Skew        Kurt  RawIntDen   Ch  Frame                   geometry
# 0      6.495470   49.264313     6499.0  1.0      0    POINT (1060.740 52.916)
# 1      5.359747   40.292707    20117.0  1.0      0   POINT (1924.707 108.646)
# 2      7.443315   64.997045     8964.0  1.0      0   POINT (1832.068 209.682)
# 3      4.014940   26.900297    63240.0  1.0      0   POINT (1443.338 271.222)
# 4      2.350462    6.953914    51144.0  1.0      0   POINT (1711.011 213.685)
# ...         ...         ...        ...  ...    ...                        ...
# 4779   1.336742    2.357870   237901.0  1.0    120   POINT (305.073 1927.625)
# 4780  12.504429  185.432231     3235.0  1.0    120  POINT (1919.232 1981.047)
# 4781   2.371847    6.521984    62034.0  1.0    120  POINT (1415.496 1963.454)
# 4782   3.957095   18.190697   150717.0  1.0    120   POINT (744.047 1997.295)
# 4783   4.246775   22.962296    20305.0  1.0    120   POINT (482.141 1999.206)
#
# [4784 rows x 14 columns]

# %%
showPolygonRoi = scyjava.jimport('ij.gui.PolygonRoi')
Overlay = scyjava.jimport('ij.gui.Overlay')
Regions = scyjava.jimport('net.imglib2.roi.Regions')
LabelRegions = scyjava.jimport('net.imglib2.roi.labeling.LabelRegions')
ZProjector = scyjava.jimport('ij.plugin.ZProjector')()
ov = Overlay()

# %%
def collapse_z(raw_dataset, output_files, method='sum', verbose=True):
    """Stack multiple z slices for each timepoint.

    If I understand Jacques' explanation of the quantification methods
    correctly, they sometimes (often?) perform better on the
￼
￼
￼
￼

    z-integration of pixels at each timepoint.  This function performs
    that and sends the stacked slices to the output directory and adds
    the filenames to the output_files dictionary.
    """
    cellpose_slices = list(output_files.keys())
    slice_number = 0
    collapsed_slices = []
    for slice_name in cellpose_slices:
        output_directory = os.path.dirname(output_files[slice_name]['output_txt'])
        collapsed_directory = os.path.dirname(output_directory)
        collapsed_directory = f"{collapsed_directory}/collapsed"
        os.makedirs(collapsed_directory, exist_ok=True)
        output_filename = Path(f"{collapsed_directory}/frame{slice_number}.tif").as_posix()
        output_files[slice_name]['collapsed_file'] = output_filename
        if os.path.exists(output_filename):
            if verbose:
                print(f"Skipping {output_filename}, it already exists.")
        else:
            larger_slice = raw_dataset[:, :, :, :, slice_number]
            imp = ij.py.to_imageplus(larger_slice)
            z_projector_result = ZProjector.run(imp, method)
            ## z_projector_mask = ij.IJ.run(z_projector_result, "Convert to Mask", "method=Otsu background=Light")
            z_collapsed_image = ij.py.from_java(z_projector_result)
            z_collapsed_dataset = ij.py.to_dataset(z_collapsed_image)
            saved = ij.io().save(z_collapsed_dataset, output_filename)
            if verbose:
                print(f"Saving image {output_filename}.")
        slice_number = slice_number + 1
    return output_files


def convert_slices_to_pandas(slices, verbose=False):
    """Dump the cellpose_result slice data to a single df.

    There is no good reason for me to store the data as a series of
    dataframes within a dictionary except I want to get more
    comfortable with python datastructures.  Thus, this function
    should be extraneous, but serves as a way to go from my hash to a
    single df.
    """
    concatenated = pandas.DataFrame()
    slice_keys = list(slices.keys())
    slice_counter = 0
    for k in slice_keys:
        slice_counter = slice_counter + 1
        current_slice = slices[k]
        if verbose:
            print(f"The slice is {k}")
        slice_number = current_slice['slice_number']
        slice_data = current_slice['measurements']
        slice_data['Frame'] = slice_number
        if slice_counter == 1:
            concatenated = slice_data
        else:
            concatenated = pandas.concat([concatenated, slice_data])
    ## This is a little silly, but I couldn't remember that the index attribute
    ## is the numeric rowname for a moment
    ## The reset_index() does what it says on the tine, and changes the 1:19, 1:20, etc
    ## of each individual time Frame to a single range of 1:2000
    concatenated.index = concatenated.reset_index().index
    return concatenated


def create_cellpose_rois(output_files, ij, raw_image, imp, collapsed=False, verbose=True,
                         delete = False, max_frames = 3):
    """Read the text cellpose output files, generate ROIs."""
    cellpose_slices = list(output_files.keys())
    data_info = {}
    for element in range(len(raw_image.dims)):
        name = raw_image.dims[element]
        data_info[name] = raw_image.shape[element]
    num_times = data_info['Time'] + 1
    num_channels = data_info['Channel']
    num_z = data_info['Z']

    Overlay = scyjava.jimport('ij.gui.Overlay')
    ov = Overlay()
    ## Set the initial time/Channel/Z
    time_set = imp.setT(1)
    Z_set = imp.setZ(1)
    C_set = imp.setC(1)

    rm = ij.RoiManager.getRoiManager()
    rm.runCommand("Associated", "true")
    ## rm.runCommand("show All with labels")
    slice_directory = ''
    print("Starting to iterate over times.")
    for timepoint in range(1, num_times):
        frame_number = timepoint - 1 ## I used 0-indexed for the frames.
        slice_name = f"frame_{frame_number}"
        input_tif = output_files[slice_name]['input_file']
        slice_directory_name = os.path.basename(os.path.dirname(os.path.dirname(input_tif)))
        input_txt = output_files[slice_name]['output_txt']
        input_mask = output_files[slice_name]['output_mask']
        ## The logic for this was taken from:
        ## https://stackoverflow.com/questions/73849418/is-there-any-way-to-switch-imagej-macro-code-to-python3-code
        txt_fh = open(input_txt, 'r')
        roi_stats = defaultdict(list)
        ## Now get the slice for this timepoint from the raw data
        for line in txt_fh:
            xy = line.rstrip().split(",")
            xy_coords = [int(element) for element in xy if element not in '']
            x_coords = [int(element) for element in xy[::2] if element not in '']
            y_coords = [int(element) for element in xy[1::2] if element not in '']
            xcoords_jint = JArray(JInt)(x_coords)
            ycoords_jint = JArray(JInt)(y_coords)
            polygon_roi_instance = scyjava.jimport('ij.gui.PolygonRoi')
            roi_instance = scyjava.jimport('ij.gui.Roi')
            imported_polygon = polygon_roi_instance(xcoords_jint, ycoords_jint,
                                                    len(x_coords), int(roi_instance.POLYGON))
            imp.setRoi(imported_polygon)
            added = rm.addRoi(imported_polygon)
            roi_count = rm.getCount() ## Get the current number of ROIs, 1 indexed.
            roi_count = rm.getCount()
            roi_zero_idx = roi_count - 1
            selected = rm.select(roi_zero_idx)
            time_set = imp.setT(timepoint)
            updated = rm.runCommand("Update")
            print(f"Finished time: {timepoint} ROI: {roi_count}")
        txt_fh.close()
    imp.show()
    roi_index = JArray(JInt)(range(0, rm.getCount()))
    rm.setSelectedIndexes(roi_index)
    rm.runCommand('Save', f"{slice_directory_name}.zip")
    if delete:
        rm.runCommand('Delete')
    return output_files


## Relevant options:
## batch_size(increase for more parallelization), channels(two element list of two element
## channels to segment; the first is the segment, second is optional nucleus;
## internal elements are color channels to query, so [[0,0],[2,3]] means do main cells in
## grayscale and a second with cells in blue, nuclei in green.
## channel_axis, z_axis ? invert (T/F flip pixels from b/w I assume),
## normalize(T/F percentile normalize the data), diameter, do_3d,
## anisotropy (rescaling factor for 3d segmentation), net_avg (average models),
## augment ?, tile ?, resample, interp, flow_threshold, cellprob_threshold (interesting),
## min_size (turned off with -1), stitch_threshold ?, rescale ?.
def invoke_cellpose(input_directory, model_file, channels=[[0, 0]], diameter=160,
                    threshold=0.4, do_3D=False, batch_size=64, verbose=True, gpu=True):
    """Invoke cellpose using individual slices.

    This takes the series of slices from separate_slices() and sends
    them to cellpose with a specific model.  The dictionary it returns
    is the primary datastructure for the various functions which follow.
    """

    ## Relevant options:
    ## model_type(cyto, nuclei, cyto2), net_avg(T/F if load built in networks and average them)
    model = models.CellposeModel(gpu=gpu, pretrained_model=model_file)
    slice_directory = Path(f"{input_directory}/slices").as_posix()
    files = get_image_files(slice_directory, '_masks', look_one_level_down=False)
    needed_imgs = []
    output_masks = []
    output_txts = []
    output_files = defaultdict(dict)
    existing_files = 0
    count = 0
    for one_file in files:
        print(f"Reading {one_file}")
        cp_output_directory = Path(f"{input_directory}/cellpose").as_posix()
        os.makedirs(cp_output_directory, exist_ok=True)
        f_name = os.path.basename(one_file)
        f_name = os.path.splitext(f_name)[0]
        start_mask = Path(f"{slice_directory}/{f_name}_cp_masks.png").as_posix()
        output_mask = Path(f"{cp_output_directory}/{f_name}_cp_masks.png").as_posix()
        start_txt = Path(f"{slice_directory}/{f_name}_cp_outlines.txt").as_posix()
        output_txt = Path(f"{cp_output_directory}/{f_name}_cp_outlines.txt").as_posix()
        print(f"Adding new txt file: {output_txt}")
        output_files[f_name]['input_file'] = one_file
        output_files[f_name]['start_mask'] = start_mask
        output_files[f_name]['output_mask'] = output_mask
        output_files[f_name]['start_txt'] = start_txt
        output_files[f_name]['output_txt'] = output_txt
        output_files[f_name]['exists'] = False
        if (os.path.exists(start_txt) or os.path.exists(output_txt)):
            existing_files = existing_files + 1
            print(f"This file already exists: {start_txt}")
            output_files[f_name]['exists'] = True
        else:
            print(f"This file does not exist: {start_txt}")
            img = imread(one_file)
            needed_imgs.append(img)
        count = count + 1
    nimg = len(needed_imgs)
    if verbose and nimg > 0:
        print(f"Reading {nimg} images, starting cellpose.")
        masks, flows, styles = model.eval(needed_imgs, diameter=diameter,
                                          channels=channels, flow_threshold=threshold,
                                          do_3D=do_3D, batch_size=batch_size)
        saved = io.save_to_png(needed_imgs, masks, flows, files)
    else:
        print("Returning the output files.")
    return output_files


def move_cellpose_output(output_files, verbose=False):
    """Cellpose puts its output files into the cwd, I want them in specific directories."""
    print(f"Moving cellpose outputs to the cellpose output directory.")
    output_filenames = list(output_files.keys())
    for f_name in output_filenames:
        output_file = output_files[f_name]['output_mask']
        if (os.path.exists(output_file)):
            if verbose:
                print("The output already exists.")
        else:
            if verbose:
                print(f"Moving {output_files[f_name]['start_mask']} to {output_file}")
            mask_moved = shutil.move(output_files[f_name]['start_mask'],
                                     output_files[f_name]['output_mask'])
            txt_moved = shutil.move(output_files[f_name]['start_txt'],
                                    output_files[f_name]['output_txt'])


def nearest_cells_over_time(df, max_dist=20.0, max_prop=0.7, x_column='X',
                            y_column='Y', verbose=True):
    """Trace cells over time

    If I understand Jacques' goals correctly, the tracing of cells
    over time should be a reasonably tractable problem for the various
    geo-statistics tools to handle; their whole purpose is to
    calculate n-dimensional distances.  So, let us pass my df to one
    of them and see what happens!

    Upon completion, we should get an array(dictionary? I forget) of
    arrays where each primary key is the top-level cell ID.  Each
    internal array is the set of IDs from the geopandas dataframe,
    which contains all of the measurements.  Thus, we can easily
    extract the data for individual cells and play with it.
    """
    gdf = geopandas.GeoDataFrame(
        df, geometry=geopandas.points_from_xy(df[x_column], df[y_column]))

    final_time = gdf.Frame.max()
    pairwise_distances = []
    for start_time in range(1, final_time):
        i = start_time
        j = i + 1
        ti_idx = gdf.Frame == i
        tj_idx = gdf.Frame == j
        if verbose:
            print(f"Getting distances of dfs {i} and {j}.")
        ti = gdf[ti_idx]
        tj = gdf[tj_idx]
        ti_rows = ti.shape[0]
        tj_rows = tj.shape[0]
        titj = geopandas.sjoin_nearest(ti, tj, distance_col="pairwise_dist")
        pairwise_distances.append(titj)

    id_counter = 0
    ## Cell IDs pointing to a list of cells
    traced = {}
    ## Endpoints pointing to the cell IDs
    ends = {}
    for i in range(0, final_time - 1):
        query = pairwise_distances[i]
        passed_idx = query.pairwise_dist <= max_dist
        failed_idx = query.pairwise_dist > max_dist
        if failed_idx.sum() > 0:
            if verbose:
                print(f"Skipped {failed_idx.sum()} elements in segment {i}.")
        query = query[passed_idx]

        #prop_change = query.Area_left / query.Area_right
        #increased_idx = prop_change > 1.0
        #prop_change[increased_idx] = 1.0 / prop_change[increased_idx]
        #failed_idx = prop_change < max_prop
        #passed_idx = prop_change >= max_prop
        #if failed_idx.sum() > 0:
        #    if verbose:
        #        skip_string = (
        #            f"Skipped {failed_idx.sum()} elements in segment {i} ",
        #            f"because the size changed too much.",
        #        )
        #        print(skip_string)
        #    query = query[passed_idx]

        for row in query.itertuples():
            start_cell = row.Index
            end_cell = row.index_right
            if start_cell in ends.keys():
                cell_id = ends[start_cell]
                current_value = traced[cell_id]
                current_value.append(end_cell)
                traced[cell_id] = current_value
                ends[end_cell] = cell_id
            else:
                id_counter = id_counter + 1
                traced[id_counter] = [start_cell, end_cell]
                ends[end_cell] = id_counter
    return traced


def separate_slices(input_file, ij, wanted_x=True, wanted_y=True, wanted_z=1,
    wanted_channel=2, cpus=8, overwrite=False, verbose=True):
    """Slice an image in preparation for cellpose.

    Eventually this should be smart enough to handle arbitrary
    x,y,z,channels,times as well as able to use multiple cpus for
    saving the data.  In its current implementation, it only saves 1
    z, 1 channel for every frame of an image into a series of files in
    its output directory.
    """

    input_base = os.path.basename(input_file)
    input_dir = os.path.dirname(input_file)
    input_name = os.path.splitext(input_base)[0]
    output_directory = Path(f"{input_dir}/outputs/{input_name}_z{wanted_z}").as_posix()
    slice_directory = Path(f"{output_directory}/slices").as_posix()
    os.makedirs(output_directory, exist_ok=True)
    os.makedirs(slice_directory, exist_ok=True)
    if verbose:
        print("Starting to open the input file, this takes a moment.")
    raw_dataset = ij.io().open(input_file)
    if verbose:
        print(f"Opened input file, writing images to {output_directory}")

    data_info = {}
    for element in range(len(raw_dataset.dims)):
        name = raw_dataset.dims[element]
        data_info[name] = raw_dataset.shape[element]
    if verbose:
        print(
            f"This dataset has dimensions: X:{data_info['X']}",
            f"Y:{data_info['Y']} Z:{data_info['Z']} Time:{data_info['Time']}",
        )

    slices = []
    for timepoint in range(data_info['Time']):
        wanted_slice = raw_dataset[:, :, wanted_channel, wanted_z, timepoint]
        slice_data = ij.py.to_dataset(wanted_slice)
        output_filename = Path(f"{output_directory}/slices/frame_{timepoint}.tif").as_posix()
        if os.path.exists(output_filename):
            if overwrite:
                print(f"Rewriting {output_filename}")
                os.remove(output_filename)
                saved = ij.io().save(slice_data, output_filename)
            else:
                if verbose:
                    print(f"Skipping {output_filename}, it already exists.")
        else:
            saved = ij.io().save(slice_data, output_filename)
            if verbose:
                print(f"Saving image {input_name}_{timepoint}.")
        slices.append(wanted_slice)
    print(f"Returning the output directory: {output_directory}")
    return raw_dataset, slices, output_directory


## The following is from a mix of a couple of implementations I found:
## https://pyimagej.readthedocs.io/en/latest/Classic-Segmentation.html
## an alternative method may be taken from:
## https://pyimagej.readthedocs.io/en/latest/Classic-Segmentation.html#segmentation-workflow-with-imagej2
## My goal is to pass the ROI regions to this function and create a similar df.
def slices_to_roi_measurements(cellpose_result, ij, collapsed=False, verbose=True):
    """Read the text cellpose output files, generate ROIs, and measure.

    I think there are better ways of accomplishing this task than
    using ij.IJ.run(); but this seems to work...  Upon completion,
    this function should add a series of dataframes to the
    cellpose_result dictionary which comprise the various metrics from
    ImageJ's measurement function of the ROIs detected by cellpose.
    """

    showPolygonRoi = scyjava.jimport('ij.gui.PolygonRoi')
    Overlay = scyjava.jimport('ij.gui.Overlay')
    Regions = scyjava.jimport('net.imglib2.roi.Regions')
    LabelRegions = scyjava.jimport('net.imglib2.roi.labeling.LabelRegions')
    ZProjector = scyjava.jimport('ij.plugin.ZProjector')()
    ov = Overlay()

    output_dict = cellpose_result
    cellpose_slices = list(cellpose_result.keys())
    slice_number = 0
    for slice_name in cellpose_slices:
        output_dict[slice_name]['slice_number'] = slice_number
        input_tif = ''
        if collapsed:
            input_tif = cellpose_result[slice_name]['collapsed_file']
        else:
            input_tif = cellpose_result[slice_name]['input_file']
        slice_dataset = ij.io().open(input_tif)
        slice_data = ij.py.to_imageplus(slice_dataset)
        input_txt = cellpose_result[slice_name]['output_txt']
        input_mask = cellpose_result[slice_name]['output_mask']
        if verbose:
            print(f"Processing cellpose outline: {input_txt}")
            print(f"Measuring: {input_tif}")
        # convert Dataset to ImagePlus
        imp = ij.py.to_imageplus(slice_data)
        rm = ij.RoiManager.getRoiManager()
        rm.runCommand("Associated", "true")
        rm.runCommand("show All with labels")
        ## The logic for this was taken from:
        ## https://stackoverflow.com/questions/73849418/is-there-any-way-to-switch-imagej-macro-code-to-python3-code
        txt_fh = open(input_txt, 'r')
        set_string = f'Set Measurements...'
        measure_string = f'area mean min centroid median skewness kurtosis integrated stack redirect=None decimal=3'
        ij.IJ.run(set_string, measure_string)
        roi_stats = defaultdict(list)
        for line in txt_fh:
            xy = line.rstrip().split(",")
            xy_coords = [int(element) for element in xy if element not in '']
            x_coords = [int(element) for element in xy[::2] if element not in '']
            y_coords = [int(element) for element in xy[1::2] if element not in '']
            xcoords_jint = JArray(JInt)(x_coords)
            ycoords_jint = JArray(JInt)(y_coords)
            polygon_roi_instance = scyjava.jimport('ij.gui.PolygonRoi')
            roi_instance = scyjava.jimport('ij.gui.Roi')
            imported_polygon = polygon_roi_instance(
                xcoords_jint, ycoords_jint, len(x_coords), int(roi_instance.POLYGON)
            )
            imp.setRoi(imported_polygon)
            rm.addRoi(imported_polygon)
            ij.IJ.run(imp, 'Measure', '')
        ## rm.runCommand('Update')  ## I think the update command needs an open image to function.
        slice_result = ij.ResultsTable.getResultsTable()
        slice_table = ij.convert().convert(
            slice_result, scyjava.jimport('org.scijava.table.Table')
        )
        slice_measurements = ij.py.from_java(slice_table)
        output_dict[slice_name]['measurements'] = slice_measurements
        ij.IJ.run('Clear Results')
        txt_fh.close()
        imp.setOverlay(ov)
        imp.getProcessor().resetMinAndMax()
        slice_number = slice_number + 1
    return output_dict

# %%
raw_dataset, saved_slices, output_directory = separate_slices(input_file, ij, wanted_z = 2,
                                                              wanted_channel = 3)
# Out:
# [java.lang.Enum.toString] ZeissCZIReader initializing /home/saka/Documents/Lab stuff/confocal/exp2/Experiment-1647-Split Scenes-01.czi
# [WARN] Unknown DetectorType value 'GaAsP-PMT' will be stored as "Other"
# [java.lang.Enum.toString] [WARN] Unknown DetectorType value 'GaAsP-PMT' will be stored as "Other"
# [WARN] Unknown DetectorType value 'GaAsP-PMT' will be stored as "Other"
# [java.lang.Enum.toString] [WARN] Unknown DetectorType value 'GaAsP-PMT' will be stored as "Other"
# [WARN] Unknown DetectorType value 'GaAsP-PMT' will be stored as "Other"
# [java.lang.Enum.toString] [WARN] Unknown DetectorType value 'GaAsP-PMT' will be stored as "Other"
# [WARN] Unknown DetectorType value 'Multialkali-PMT' will be stored as "Other"
# [java.lang.Enum.toString] [WARN] Unknown DetectorType value 'Multialkali-PMT' will be stored as "Other"

# %%
output_files = invoke_cellpose(output_directory, '/home/saka/Documents/CP_20220523_104016')

# %%
move_cellpose_output(output_files)

# %%
output_files = collapse_z(raw_dataset, output_files)

# %%
slice_measurements = slices_to_roi_measurements(output_files, ij, collapsed = True)

# %%
updated = create_cellpose_rois(output_files, raw_image, collapsed = True)

# %%
concatenated = convert_slices_to_pandas(slice_measurements)

# %%
nearest = nearest_cells_over_time(concatenated, max_dist = 20.0,
                                  x_column = 'X', y_column = 'Y')

# %%
cell_id = 291
cell_idx = nearest[cell_id]
cell_data = concatenated.loc[cell_idx]
len(cell_data)
# Out:
# 4

# %%
cell_data = cell_data.reset_index()

scatter = plt.scatter(cell_data['X'], cell_data['Y'])
final_row = cell_data.index.max()
for start_time in range(0, final_row - 1):
    ti_idx = cell_data.index == start_time
    tj_idx = cell_data.index == start_time + 1
    p1x = cell_data[ti_idx].X
    p2x = cell_data[tj_idx].X
    p1y = cell_data[ti_idx].Y
    p2y = cell_data[tj_idx].Y
    x_points = [p1x, p2x]
    y_points = [p1y, p2y]
    plt.plot(x_points, y_points)
finalm1_idx = cell_data.index == final_row - 1
final_idx = cell_data.index == final_row
finalm1_x = cell_data[finalm1_idx].X
final_x = cell_data[final_idx].X
finalm1_y = cell_data[finalm1_idx].Y
final_y = cell_data[final_idx].Y
x_points = [finalm1_x, final_x]
y_points = [finalm1_y, final_y]
plt.plot(x_points, y_points)
plt.show()

# %%
seaborn.violinplot(data = cell_data.Area)
plt.show()

# %% [markdown]
# ## Test Area

# %%
raw_image = ij.io().open('/home/saka/Documents/Lab stuff/confocal/exp2/outputs/Experiment-1647-Split Scenes-01_z2/MAX_slices.tif')
#raw_image = ij.io().open(input_file)
shown = ij.ui().show(raw_image)
imp = ij.py.to_imageplus(raw_image)

# %%
rm = ij.RoiManager.getRoiManager()

# %%
import random
colors = ["black", "blue", "cyan", "green", "magenta", "orange", "red", "white", "yellow"]

cell_id = nearest.keys()
for i in cell_id :
    cell_idx = nearest[i]
    random_color = random.choice(colors)
    #cell_data = concatenated.loc[cell_idx]
# Iterate over the cell_idx values
    for idx in cell_idx:
        # Get the ROI from the ROI Manager 
        roi = rm.select(idx - 1)
        overlay_command = f"Overlay.addSelection('{random_color}', 5);"
        # Add the ROI to the array
        ij.py.run_macro(overlay_command)

# %%
prout = nearest[3] + nearest[47] + nearest[75] + nearest[117]      #this works to concatenate different cell ids.

# %%
print(concatenated)

# %%
for idx in prout:
    roi = rm.select(idx - 1)
    overlay_command = f"Overlay.addSelection('Red',5);"
    ij.py.run_macro(overlay_command)
